# %% [markdown]
# # Tempo Client Demo

# %%
import sys
import asyncio
import aiohttp
import os
import pandas as pd
from typing import List, Dict

sys.path.append ('..')
import utils

project_path = os.path.join('..', '..', 'scale')

sys.path.append(project_path)

utils.add_to_sys_path(project_path)


from scale.backends.tempo_client import TempoClient
from scale.modeler.src.models import Span, Trace

# %% [markdown]
# ## Forward the tempo port to localhost
#
# If you cannot reach the node port, or just want to forward it anyway
#
# **NOTE:** run this from another command window

# %%
# %%bash
#
# kubectl port-forward -n monitoring svc/tempo 3200:3200

# %%
TEMPO_URL = "http://localhost:3200"

# If using nodeport
# TEMPO_URL = "http://192.168.49.2:32000"

# %% [markdown]
# ## Create TempoClient instance

# %%
tempo_client = TempoClient(TEMPO_URL)

# %% [markdown]
# ## Check the TempoClient API

# %%
help(TempoClient)
# Out:
# Help on class TempoClient in module scale.backends.tempo_client:
#
# class TempoClient(builtins.object)
#  |  TempoClient(tempo_url)
#  |
#  |  Convenience class for interacting with Tempo gRPC API
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, tempo_url)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  async build_span_df(self, start_delta: int, limit: int) -> pandas.core.frame.DataFrame
#  |      Generate a pandas data frame containing trace data in the following form
#  |      [TraceID,SpanID,ParentID,OperationName,StartTimeUnixNano,Duration]
#  |
#  |      Args:
#  |          start_delta (int): Number of seconds in past to search for traces.
#  |          limit (int): Limit number of records from Tempo. Defaults to 1000.
#  |
#  |      Returns:
#  |          pd.DataFrame: data frame containing trace data
#  |
#  |  async find_trace_by_id(self, session: aiohttp.client.ClientSession, trace_id: str) -> opentelemetry.proto.trace.v1.trace_pb2.TracesData
#  |      Find a trace in Tempo by it's trace id
#  |
#  |      Args:
#  |          session (aiohttp.ClientSession): aiohttp Session
#  |          trace_id (str): ID of trace
#  |
#  |      Returns:
#  |          TraceByIDResponse: response from Tempo containing trace info
#  |
#  |  async search(self, session: aiohttp.client.ClientSession, start_delta: int, limit: int) -> list[str]
#  |      Search Tempo for arbitrary traces
#  |
#  |      Args:
#  |          session (aiohttp.ClientSession): aiohttp Session
#  |          start_delta (int): Number of seconds in past to search for traces.
#  |          limit (int): maximum among of traces to pull back from Tempo
#  |      Returns:
#  |          list[str]: trace ids from tempo meeting request criteria
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  QUERY_HEADERS = {'Accept': 'application/protobuf'}

# %% [markdown]
# ## Get Recent Trace IDs

# %%
tcp_connection = aiohttp.TCPConnector(limit=20)
start_delta = 60 # get the last minute of traces

async with aiohttp.ClientSession(connector=tcp_connection) as session:
    trace_ids = await tempo_client.search(session=session, start_delta=start_delta, limit=10)

trace_ids
# Out:
# ['6411b1dfe627b258d4a0ee1c1e6c0b9',
#  '47ed37eb8979935be8d21a90d29fade',
#  'abf78b84f9b3d35a47bcb32a2cfed83',
#  '884997d3f6d6bafbf275f174f622524',
#  '6882ac8b7ac8a901c3fee34f81a365',
#  'c041c1297a474e53a971e798194ad0f',
#  '8a8a3d5e8f24ff969e6d6505b2e76a3',
#  'a48b537294d6770be240d5121859ccd',
#  '968df5850ffa32b525c263bac78dd54',
#  '12661c50006cff76394966c5252100']

# %% [markdown]
# ## Get Trace By ID

# %%
tcp_connection = aiohttp.TCPConnector(limit=20)
start_delta = 60 # get the last minute of traces

trace_id = trace_ids[1]
async with aiohttp.ClientSession(connector=tcp_connection) as session:
    trace = await tempo_client.find_trace_by_id(session=session, trace_id=trace_id)

trace
# Out:
# resource_spans {
#   resource {
#     attributes {
#       key: "telemetry.sdk.language"
#       value {
#         string_value: "python"
#       }
#     }
#     attributes {
#       key: "telemetry.sdk.name"
#       value {
#         string_value: "opentelemetry"
#       }
#     }
#     attributes {
#       key: "telemetry.sdk.version"
#       value {
#         string_value: "1.23.0"
#       }
#     }
#     attributes {
#       key: "service.namespace"
#       value {
#         string_value: "opentelemetry-demo"
#       }
#     }
#     attributes {
#       key: "service.version"
#       value {
#         string_value: "1.11.1"
#       }
#     }
#     attributes {
#       key: "service.name"
#       value {
#         string_value: "loadgenerator"
#       }
#     }
#   }
#   scope_spans {
#     scope {
#       name: "opentelemetry.instrumentation.requests"
#       version: "0.44b0"
#     }
#     spans {
#       trace_id: "\004~\323~\270\227\2315\276\215!\251\r)\372\336"
#       span_id: "h\253\300U\337\370\030\302"
#       name: "GET"
#       kind: SPAN_KIND_CLIENT
#       start_time_unix_nano: 1730002534903897570
#       end_time_unix_nano: 1730002534911258581
#       attributes {
#         key: "http.method"
#         value {
#           string_value: "GET"
#         }
#       }
#       attributes {
#         key: "http.url"
#         value {
#           string_value: "http://otel-demo-frontendproxy:8080/api/recommendations?productIds=66VCHSJNUP"
#         }
#       }
#       attributes {
#         key: "http.status_code"
#         value {
#           int_value: 200
#         }
#       }
#       status {
#       }
#     }
#   }
# }
# resource_spans {
#   resource {
#     attributes {
#       key: "telemetry.sdk.language"
#       value {
#         string_value: "nodejs"
#       }
#     }
#     attributes {
#       key: "telemetry.sdk.name"
#       value {
#         string_value: "opentelemetry"
#       }
#     }
#     attributes {
#       key: "telemetry.sdk.version"
#       value {
#         string_value: "1.25.1"
#       }
#     }
#     attributes {
#       key: "container.id"
#       value {
#         string_value: "ad7b0f5e4688472453720ebfb0e0a213ab483d58dd15f2167e910a592a0aee02"
#       }
#     }
#     attributes {
#       key: "service.namespace"
#       value {
#         string_value: "opentelemetry-demo"
#       }
#     }
#     attributes {
#       key: "service.version"
#       value {
#         string_value: "1.11.1"
#       }
#     }
#     attributes {
#       key: "host.name"
#       value {
#         string_value: "otel-demo-frontend-f6c6fbf66-qt54d"
#       }
#     }
#     attributes {
#       key: "host.arch"
#       value {
#         string_value: "amd64"
#       }
#     }
#     attributes {
#       key: "os.type"
#       value {
#         string_value: "linux"
#       }
#     }
#     attributes {
#       key: "os.version"
#       value {
#         string_value: "6.1.106-1-MANJARO"
#       }
#     }
#     attributes {
#       key: "process.pid"
#       value {
#         int_value: 17
#       }
#     }
#     attributes {
#       key: "process.executable.name"
#       value {
#         string_value: "node"
#       }
#     }
#     attributes {
#       key: "process.executable.path"
#       value {
#         string_value: "/usr/local/bin/node"
#       }
#     }
#     attributes {
#       key: "process.command_args"
#       value {
#         array_value {
#           values {
#             string_value: "/usr/local/bin/node"
#           }
#           values {
#             string_value: "--require"
#           }
#           values {
#             string_value: "./Instrumentation.js"
#           }
#           values {
#             string_value: "/app/server.js"
#           }
#         }
#       }
#     }
#     attributes {
#       key: "process.runtime.version"
#       value {
#         string_value: "20.16.0"
#       }
#     }
#     attributes {
#       key: "process.runtime.name"
#       value {
#         string_value: "nodejs"
#       }
#     }
#     attributes {
#       key: "process.runtime.description"
#       value {
#         string_value: "Node.js"
#       }
#     }
#     attributes {
#       key: "process.command"
#       value {
#         string_value: "/app/server.js"
#       }
#     }
#     attributes {
#       key: "process.owner"
#       value {
#         string_value: "nextjs"
#       }
#     }
#     attributes {
#       key: "service.name"
#       value {
#         string_value: "frontend"
#       }
#     }
#   }
#   scope_spans {
#     scope {
#       name: "@opentelemetry/instrumentation-http"
#       version: "0.52.1"
#     }
#     spans {
#       trace_id: "\004~\323~\270\227\2315\276\215!\251\r)\372\336"
#       span_id: "\200Q\177MW\326\374\347"
#       parent_span_id: "\026H\345\247\001\263\274G"
#       name: "GET"
#       kind: SPAN_KIND_SERVER
#       start_time_unix_nano: 1730002534904000000
#       end_time_unix_nano: 1730002534909618453
#       attributes {
#         key: "http.host"
#         value {
#           string_value: "otel-demo-frontendproxy:8080"
#         }
#       }
#       attributes {
#         key: "net.host.name"
#         value {
#           string_value: "otel-demo-frontendproxy"
#         }
#       }
#       attributes {
#         key: "http.scheme"
#         value {
#           string_value: "http"
#         }
#       }
#       attributes {
#         key: "http.target"
#         value {
#           string_value: "/api/recommendations?productIds=66VCHSJNUP"
#         }
#       }
#       attributes {
#         key: "http.user_agent"
#         value {
#           string_value: "python-requests/2.31.0"
#         }
#       }
#       attributes {
#         key: "http.flavor"
#         value {
#           string_value: "1.1"
#         }
#       }
#       attributes {
#         key: "net.transport"
#         value {
#           string_value: "ip_tcp"
#         }
#       }
#       attributes {
#         key: "net.host.ip"
#         value {
#           string_value: "10.244.0.92"
#         }
#       }
#       attributes {
#         key: "net.host.port"
#         value {
#           int_value: 8080
#         }
#       }
#       attributes {
#         key: "net.peer.ip"
#         value {
#           string_value: "10.244.0.80"
#         }
#       }
#       attributes {
#         key: "net.peer.port"
#         value {
#           int_value: 52760
#         }
#       }
#       attributes {
#         key: "http.status_text"
#         value {
#           string_value: "OK"
#         }
#       }
#       attributes {
#         key: "http.method"
#         value {
#           string_value: "GET"
#         }
#       }
#       attributes {
#         key: "http.url"
#         value {
#           string_value: "http://otel-demo-frontendproxy:8080/api/recommendations?productIds=66VCHSJNUP"
#         }
#       }
#       attributes {
#         key: "http.status_code"
#         value {
#           int_value: 200
#         }
#       }
#       status {
#       }
#     }
#   }
# }
# resource_spans {
#   resource {
#     attributes {
#       key: "service.namespace"
#       value {
#         string_value: "opentelemetry-demo"
#       }
#     }
#     attributes {
#       key: "service.version"
#       value {
#         string_value: "1.11.1"
#       }
#     }
#     attributes {
#       key: "service.name"
#       value {
#         string_value: "frontendproxy"
#       }
#     }
#   }
#   scope_spans {
#     scope {
#     }
#     spans {
#       trace_id: "\004~\323~\270\227\2315\276\215!\251\r)\372\336"
#       span_id: "\315!\346\t\262\242\331\\"
#       parent_span_id: "h\253\300U\337\370\030\302"
#       name: "ingress"
#       kind: SPAN_KIND_SERVER
#       start_time_unix_nano: 1730002534904568000
#       end_time_unix_nano: 1730002534910532000
#       attributes {
#         key: "node_id"
#         value {
#           string_value: ""
#         }
#       }
#       attributes {
#         key: "zone"
#         value {
#           string_value: ""
#         }
#       }
#       attributes {
#         key: "guid:x-request-id"
#         value {
#           string_value: "eb4546a6-1d79-91ae-b7da-ee37b582c35c"
#         }
#       }
#       attributes {
#         key: "downstream_cluster"
#         value {
#           string_value: "-"
#         }
#       }
#       attributes {
#         key: "user_agent"
#         value {
#           string_value: "python-requests/2.31.0"
#         }
#       }
#       attributes {
#         key: "http.protocol"
#         value {
#           string_value: "HTTP/1.1"
#         }
#       }
#       attributes {
#         key: "peer.address"
#         value {
#           string_value: "10.244.0.89"
#         }
#       }
#       attributes {
#         key: "request_size"
#         value {
#           string_value: "0"
#         }
#       }
#       attributes {
#         key: "response_size"
#         value {
#           string_value: "1506"
#         }
#       }
#       attributes {
#         key: "component"
#         value {
#           string_value: "proxy"
#         }
#       }
#       attributes {
#         key: "upstream_cluster"
#         value {
#           string_value: "frontend"
#         }
#       }
#       attributes {
#         key: "upstream_cluster.name"
#         value {
#           string_value: "frontend"
#         }
#       }
#       attributes {
#         key: "http.status_code"
#         value {
#           string_value: "200"
#         }
#       }
#       attributes {
#         key: "response_flags"
#         value {
#           string_value: "-"
#         }
#       }
#       attributes {
#         key: "http.method"
#         value {
#           string_value: "GET"
#         }
#       }
#       attributes {
#         key: "http.url"
#         value {
#           string_value: "http://otel-demo-frontendproxy:8080/api/recommendations?productIds=66VCHSJNUP"
#         }
#       }
#       status {
#       }
#     }
#     spans {
#       trace_id: "\004~\323~\270\227\2315\276\215!\251\r)\372\336"
#       span_id: "\026H\345\247\001\263\274G"
#       parent_span_id: "\315!\346\t\262\242\331\\"
#       name: "router frontend egress"
#       kind: SPAN_KIND_CLIENT
#       start_time_unix_nano: 1730002534904662000
#       end_time_unix_nano: 1730002534910505000
#       attributes {
#         key: "http.protocol"
#         value {
#           string_value: "HTTP/1.1"
#         }
#       }
#       attributes {
#         key: "upstream_address"
#         value {
#           string_value: "10.96.155.196:8080"
#         }
#       }
#       attributes {
#         key: "peer.address"
#         value {
#           string_value: "10.96.155.196:8080"
#         }
#       }
#       attributes {
#         key: "component"
#         value {
#           string_value: "proxy"
#         }
#       }
#       attributes {
#         key: "upstream_cluster"
#         value {
#           string_value: "frontend"
#         }
#       }
#       attributes {
#         key: "upstream_cluster.name"
#         value {
#           string_value: "frontend"
#         }
#       }
#       attributes {
#         key: "http.status_code"
#         value {
#           string_value: "200"
#         }
#       }
#       attributes {
#         key: "response_flags"
#         value {
#           string_value: "-"
#         }
#       }
#       status {
#       }
#     }
#   }
# }
# resource_spans {
#   resource {
#     attributes {
#       key: "telemetry.sdk.language"
#       value {
#         string_value: "nodejs"
#       }
#     }
#     attributes {
#       key: "telemetry.sdk.name"
#       value {
#         string_value: "opentelemetry"
#       }
#     }
#     attributes {
#       key: "telemetry.sdk.version"
#       value {
#         string_value: "1.25.1"
#       }
#     }
#     attributes {
#       key: "container.id"
#       value {
#         string_value: "ad7b0f5e4688472453720ebfb0e0a213ab483d58dd15f2167e910a592a0aee02"
#       }
#     }
#     attributes {
#       key: "service.namespace"
#       value {
#         string_value: "opentelemetry-demo"
#       }
#     }
#     attributes {
#       key: "service.version"
#       value {
#         string_value: "1.11.1"
#       }
#     }
#     attributes {
#       key: "host.name"
#       value {
#         string_value: "otel-demo-frontend-f6c6fbf66-qt54d"
#       }
#     }
#     attributes {
#       key: "host.arch"
#       value {
#         string_value: "amd64"
#       }
#     }
#     attributes {
#       key: "os.type"
#       value {
#         string_value: "linux"
#       }
#     }
#     attributes {
#       key: "os.version"
#       value {
#         string_value: "6.1.106-1-MANJARO"
#       }
#     }
#     attributes {
#       key: "process.pid"
#       value {
#         int_value: 17
#       }
#     }
#     attributes {
#       key: "process.executable.name"
#       value {
#         string_value: "node"
#       }
#     }
#     attributes {
#       key: "process.executable.path"
#       value {
#         string_value: "/usr/local/bin/node"
#       }
#     }
#     attributes {
#       key: "process.command_args"
#       value {
#         array_value {
#           values {
#             string_value: "/usr/local/bin/node"
#           }
#           values {
#             string_value: "--require"
#           }
#           values {
#             string_value: "./Instrumentation.js"
#           }
#           values {
#             string_value: "/app/server.js"
#           }
#         }
#       }
#     }
#     attributes {
#       key: "process.runtime.version"
#       value {
#         string_value: "20.16.0"
#       }
#     }
#     attributes {
#       key: "process.runtime.name"
#       value {
#         string_value: "nodejs"
#       }
#     }
#     attributes {
#       key: "process.runtime.description"
#       value {
#         string_value: "Node.js"
#       }
#     }
#     attributes {
#       key: "process.command"
#       value {
#         string_value: "/app/server.js"
#       }
#     }
#     attributes {
#       key: "process.owner"
#       value {
#         string_value: "nextjs"
#       }
#     }
#     attributes {
#       key: "service.name"
#       value {
#         string_value: "frontend"
#       }
#     }
#   }
#   scope_spans {
#     scope {
#       name: "next.js"
#       version: "0.0.1"
#     }
#     spans {
#       trace_id: "\004~\323~\270\227\2315\276\215!\251\r)\372\336"
#       span_id: "0\344\025\316\203\302\347\311"
#       parent_span_id: "\200Q\177MW\326\374\347"
#       name: "GET /api/recommendations?productIds=66VCHSJNUP"
#       kind: SPAN_KIND_SERVER
#       start_time_unix_nano: 1730002534905000000
#       end_time_unix_nano: 1730002534909727600
#       attributes {
#         key: "next.span_name"
#         value {
#           string_value: "GET /api/recommendations?productIds=66VCHSJNUP"
#         }
#       }
#       attributes {
#         key: "next.span_type"
#         value {
#           string_value: "BaseServer.handleRequest"
#         }
#       }
#       attributes {
#         key: "http.target"
#         value {
#           string_value: "/api/recommendations?productIds=66VCHSJNUP"
#         }
#       }
#       attributes {
#         key: "next.rsc"
#         value {
#           bool_value: false
#         }
#       }
#       attributes {
#         key: "http.method"
#         value {
#           string_value: "GET"
#         }
#       }
#       attributes {
#         key: "http.status_code"
#         value {
#           int_value: 200
#         }
#       }
#       status {
#       }
#     }
#     spans {
#       trace_id: "\004~\323~\270\227\2315\276\215!\251\r)\372\336"
#       span_id: "\346Z\332\252\340\340}\n"
#       parent_span_id: "0\344\025\316\203\302\347\311"
#       name: "executing api route (pages) /api/recommendations"
#       kind: SPAN_KIND_INTERNAL
#       start_time_unix_nano: 1730002534905000000
#       end_time_unix_nano: 1730002534909474036
#       attributes {
#         key: "next.span_name"
#         value {
#           string_value: "executing api route (pages) /api/recommendations"
#         }
#       }
#       attributes {
#         key: "next.span_type"
#         value {
#           string_value: "Node.runHandler"
#         }
#       }
#       attributes {
#         key: "http.status_code"
#         value {
#           int_value: 200
#         }
#       }
#       status {
#       }
#     }
#   }
# }
# resource_spans {
#   resource {
#     attributes {
#       key: "telemetry.sdk.language"
#       value {
#         string_value: "nodejs"
#       }
#     }
#     attributes {
#       key: "telemetry.sdk.name"
#       value {
#         string_value: "opentelemetry"
#       }
#     }
#     attributes {
#       key: "telemetry.sdk.version"
#       value {
#         string_value: "1.25.1"
#       }
#     }
#     attributes {
#       key: "container.id"
#       value {
#         string_value: "ad7b0f5e4688472453720ebfb0e0a213ab483d58dd15f2167e910a592a0aee02"
#       }
#     }
#     attributes {
#       key: "service.namespace"
#       value {
#         string_value: "opentelemetry-demo"
#       }
#     }
#     attributes {
#       key: "service.version"
#       value {
#         string_value: "1.11.1"
#       }
#     }
#     attributes {
#       key: "host.name"
#       value {
#         string_value: "otel-demo-frontend-f6c6fbf66-qt54d"
#       }
#     }
#     attributes {
#       key: "host.arch"
#       value {
#         string_value: "amd64"
#       }
#     }
#     attributes {
#       key: "os.type"
#       value {
#         string_value: "linux"
#       }
#     }
#     attributes {
#       key: "os.version"
#       value {
#         string_value: "6.1.106-1-MANJARO"
#       }
#     }
#     attributes {
#       key: "process.pid"
#       value {
#         int_value: 17
#       }
#     }
#     attributes {
#       key: "process.executable.name"
#       value {
#         string_value: "node"
#       }
#     }
#     attributes {
#       key: "process.executable.path"
#       value {
#         string_value: "/usr/local/bin/node"
#       }
#     }
#     attributes {
#       key: "process.command_args"
#       value {
#         array_value {
#           values {
#             string_value: "/usr/local/bin/node"
#           }
#           values {
#             string_value: "--require"
#           }
#           values {
#             string_value: "./Instrumentation.js"
#           }
#           values {
#             string_value: "/app/server.js"
#           }
#         }
#       }
#     }
#     attributes {
#       key: "process.runtime.version"
#       value {
#         string_value: "20.16.0"
#       }
#     }
#     attributes {
#       key: "process.runtime.name"
#       value {
#         string_value: "nodejs"
#       }
#     }
#     attributes {
#       key: "process.runtime.description"
#       value {
#         string_value: "Node.js"
#       }
#     }
#     attributes {
#       key: "process.command"
#       value {
#         string_value: "/app/server.js"
#       }
#     }
#     attributes {
#       key: "process.owner"
#       value {
#         string_value: "nextjs"
#       }
#     }
#     attributes {
#       key: "service.name"
#       value {
#         string_value: "frontend"
#       }
#     }
#   }
#   scope_spans {
#     scope {
#       name: "@opentelemetry/instrumentation-grpc"
#       version: "0.52.1"
#     }
#     spans {
#       trace_id: "\004~\323~\270\227\2315\276\215!\251\r)\372\336"
#       span_id: "\331\352Y\276\264W\375\032"
#       parent_span_id: "\346Z\332\252\340\340}\n"
#       name: "grpc.oteldemo.RecommendationService/ListRecommendations"
#       kind: SPAN_KIND_CLIENT
#       start_time_unix_nano: 1730002534905000000
#       end_time_unix_nano: 1730002534907906271
#       attributes {
#         key: "rpc.system"
#         value {
#           string_value: "grpc"
#         }
#       }
#       attributes {
#         key: "rpc.method"
#         value {
#           string_value: "ListRecommendations"
#         }
#       }
#       attributes {
#         key: "rpc.service"
#         value {
#           string_value: "oteldemo.RecommendationService"
#         }
#       }
#       attributes {
#         key: "net.peer.name"
#         value {
#           string_value: "otel-demo-recommendationservice"
#         }
#       }
#       attributes {
#         key: "net.peer.port"
#         value {
#           int_value: 8080
#         }
#       }
#       attributes {
#         key: "rpc.grpc.status_code"
#         value {
#           int_value: 0
#         }
#       }
#       status {
#       }
#     }
#     spans {
#       trace_id: "\004~\323~\270\227\2315\276\215!\251\r)\372\336"
#       span_id: ":\234\350\374\020\020&d"
#       parent_span_id: "\346Z\332\252\340\340}\n"
#       name: "grpc.oteldemo.ProductCatalogService/GetProduct"
#       kind: SPAN_KIND_CLIENT
#       start_time_unix_nano: 1730002534908000000
#       end_time_unix_nano: 1730002534908942814
#       attributes {
#         key: "rpc.system"
#         value {
#           string_value: "grpc"
#         }
#       }
#       attributes {
#         key: "rpc.method"
#         value {
#           string_value: "GetProduct"
#         }
#       }
#       attributes {
#         key: "rpc.service"
#         value {
#           string_value: "oteldemo.ProductCatalogService"
#         }
#       }
#       attributes {
#         key: "net.peer.name"
#         value {
#           string_value: "otel-demo-productcatalogservice"
#         }
#       }
#       attributes {
#         key: "net.peer.port"
#         value {
#           int_value: 8080
#         }
#       }
#       attributes {
#         key: "rpc.grpc.status_code"
#         value {
#           int_value: 0
#         }
#       }
#       status {
#       }
#     }
#     spans {
#       trace_id: "\004~\323~\270\227\2315\276\215!\251\r)\372\336"
#       span_id: "HY<\305\213?\303\246"
#       parent_span_id: "\346Z\332\252\340\340}\n"
#       name: "grpc.oteldemo.ProductCatalogService/GetProduct"
#       kind: SPAN_KIND_CLIENT
#       start_time_unix_nano: 1730002534908000000
#       end_time_unix_nano: 1730002534909073175
#       attributes {
#         key: "rpc.system"
#         value {
#           string_value: "grpc"
#         }
#       }
#       attributes {
#         key: "rpc.method"
#         value {
#           string_value: "GetProduct"
#         }
#       }
#       attributes {
#         key: "rpc.service"
#         value {
#           string_value: "oteldemo.ProductCatalogService"
#         }
#       }
#       attributes {
#         key: "net.peer.name"
#         value {
#           string_value: "otel-demo-productcatalogservice"
#         }
#       }
#       attributes {
#         key: "net.peer.port"
#         value {
#           int_value: 8080
#         }
#       }
#       attributes {
#         key: "rpc.grpc.status_code"
#         value {
#           int_value: 0
#         }
#       }
#       status {
#       }
#     }
#     spans {
#       trace_id: "\004~\323~\270\227\2315\276\215!\251\r)\372\336"
#       span_id: "\\\006\000c\030\315O\341"
#       parent_span_id: "\346Z\332\252\340\340}\n"
#       name: "grpc.oteldemo.ProductCatalogService/GetProduct"
#       kind: SPAN_KIND_CLIENT
#       start_time_unix_nano: 1730002534908000000
#       end_time_unix_nano: 1730002534908942665
#       attributes {
#         key: "rpc.system"
#         value {
#           string_value: "grpc"
#         }
#       }
#       attributes {
#         key: "rpc.method"
#         value {
#           string_value: "GetProduct"
#         }
#       }
#       attributes {
#         key: "rpc.service"
#         value {
#           string_value: "oteldemo.ProductCatalogService"
#         }
#       }
#       attributes {
#         key: "net.peer.name"
#         value {
#           string_value: "otel-demo-productcatalogservice"
#         }
#       }
#       attributes {
#         key: "net.peer.port"
#         value {
#           int_value: 8080
#         }
#       }
#       attributes {
#         key: "rpc.grpc.status_code"
#         value {
#           int_value: 0
#         }
#       }
#       status {
#       }
#     }
#     spans {
#       trace_id: "\004~\323~\270\227\2315\276\215!\251\r)\372\336"
#       span_id: "\317\355\210\031|\037\202q"
#       parent_span_id: "\346Z\332\252\340\340}\n"
#       name: "grpc.oteldemo.ProductCatalogService/GetProduct"
#       kind: SPAN_KIND_CLIENT
#       start_time_unix_nano: 1730002534908000000
#       end_time_unix_nano: 1730002534908921675
#       attributes {
#         key: "rpc.system"
#         value {
#           string_value: "grpc"
#         }
#       }
#       attributes {
#         key: "rpc.method"
#         value {
#           string_value: "GetProduct"
#         }
#       }
#       attributes {
#         key: "rpc.service"
#         value {
#           string_value: "oteldemo.ProductCatalogService"
#         }
#       }
#       attributes {
#         key: "net.peer.name"
#         value {
#           string_value: "otel-demo-productcatalogservice"
#         }
#       }
#       attributes {
#         key: "net.peer.port"
#         value {
#           int_value: 8080
#         }
#       }
#       attributes {
#         key: "rpc.grpc.status_code"
#         value {
#           int_value: 0
#         }
#       }
#       status {
#       }
#     }
#   }
# }
# resource_spans {
#   resource {
#     attributes {
#       key: "telemetry.sdk.language"
#       value {
#         string_value: "python"
#       }
#     }
#     attributes {
#       key: "telemetry.sdk.name"
#       value {
#         string_value: "opentelemetry"
#       }
#     }
#     attributes {
#       key: "telemetry.sdk.version"
#       value {
#         string_value: "1.25.0"
#       }
#     }
#     attributes {
#       key: "service.namespace"
#       value {
#         string_value: "opentelemetry-demo"
#       }
#     }
#     attributes {
#       key: "service.version"
#       value {
#         string_value: "1.11.1"
#       }
#     }
#     attributes {
#       key: "telemetry.auto.version"
#       value {
#         string_value: "0.46b0"
#       }
#     }
#     attributes {
#       key: "service.name"
#       value {
#         string_value: "recommendationservice"
#       }
#     }
#   }
#   scope_spans {
#     scope {
#       name: "opentelemetry.instrumentation.grpc"
#       version: "0.46b0"
#     }
#     spans {
#       trace_id: "\004~\323~\270\227\2315\276\215!\251\r)\372\336"
#       span_id: "\014h\tGM\301\240\t"
#       parent_span_id: "\331\352Y\276\264W\375\032"
#       name: "/oteldemo.RecommendationService/ListRecommendations"
#       kind: SPAN_KIND_SERVER
#       start_time_unix_nano: 1730002534906285769
#       end_time_unix_nano: 1730002534907991156
#       attributes {
#         key: "rpc.system"
#         value {
#           string_value: "grpc"
#         }
#       }
#       attributes {
#         key: "rpc.grpc.status_code"
#         value {
#           int_value: 0
#         }
#       }
#       attributes {
#         key: "rpc.method"
#         value {
#           string_value: "ListRecommendations"
#         }
#       }
#       attributes {
#         key: "rpc.service"
#         value {
#           string_value: "oteldemo.RecommendationService"
#         }
#       }
#       attributes {
#         key: "rpc.user_agent"
#         value {
#           string_value: "grpc-node-js/1.10.11"
#         }
#       }
#       attributes {
#         key: "net.peer.ip"
#         value {
#           string_value: "10.244.0.92"
#         }
#       }
#       attributes {
#         key: "net.peer.port"
#         value {
#           string_value: "60628"
#         }
#       }
#       attributes {
#         key: "app.products_recommended.count"
#         value {
#           int_value: 5
#         }
#       }
#       status {
#       }
#     }
#     spans {
#       trace_id: "\004~\323~\270\227\2315\276\215!\251\r)\372\336"
#       span_id: "\344i\3660\315>\233\271"
#       parent_span_id: "\277\237\"\331A\337\030N"
#       name: "/schema.v1.Service/ResolveBoolean"
#       kind: SPAN_KIND_CLIENT
#       start_time_unix_nano: 1730002534906444824
#       end_time_unix_nano: 1730002534907109541
#       attributes {
#         key: "rpc.system"
#         value {
#           string_value: "grpc"
#         }
#       }
#       attributes {
#         key: "rpc.grpc.status_code"
#         value {
#           int_value: 0
#         }
#       }
#       attributes {
#         key: "rpc.method"
#         value {
#           string_value: "ResolveBoolean"
#         }
#       }
#       attributes {
#         key: "rpc.service"
#         value {
#           string_value: "schema.v1.Service"
#         }
#       }
#       status {
#       }
#     }
#     spans {
#       trace_id: "\004~\323~\270\227\2315\276\215!\251\r)\372\336"
#       span_id: "\0214\230(43\342\234"
#       parent_span_id: "\277\237\"\331A\337\030N"
#       name: "/oteldemo.ProductCatalogService/ListProducts"
#       kind: SPAN_KIND_CLIENT
#       start_time_unix_nano: 1730002534907210495
#       end_time_unix_nano: 1730002534907810199
#       attributes {
#         key: "rpc.system"
#         value {
#           string_value: "grpc"
#         }
#       }
#       attributes {
#         key: "rpc.grpc.status_code"
#         value {
#           int_value: 0
#         }
#       }
#       attributes {
#         key: "rpc.method"
#         value {
#           string_value: "ListProducts"
#         }
#       }
#       attributes {
#         key: "rpc.service"
#         value {
#           string_value: "oteldemo.ProductCatalogService"
#         }
#       }
#       status {
#       }
#     }
#   }
# }
# resource_spans {
#   resource {
#     attributes {
#       key: "telemetry.sdk.language"
#       value {
#         string_value: "python"
#       }
#     }
#     attributes {
#       key: "telemetry.sdk.name"
#       value {
#         string_value: "opentelemetry"
#       }
#     }
#     attributes {
#       key: "telemetry.sdk.version"
#       value {
#         string_value: "1.25.0"
#       }
#     }
#     attributes {
#       key: "service.namespace"
#       value {
#         string_value: "opentelemetry-demo"
#       }
#     }
#     attributes {
#       key: "service.version"
#       value {
#         string_value: "1.11.1"
#       }
#     }
#     attributes {
#       key: "telemetry.auto.version"
#       value {
#         string_value: "0.46b0"
#       }
#     }
#     attributes {
#       key: "service.name"
#       value {
#         string_value: "recommendationservice"
#       }
#     }
#   }
#   scope_spans {
#     scope {
#       name: "recommendationservice"
#     }
#     spans {
#       trace_id: "\004~\323~\270\227\2315\276\215!\251\r)\372\336"
#       span_id: "\277\237\"\331A\337\030N"
#       parent_span_id: "\014h\tGM\301\240\t"
#       name: "get_product_list"
#       kind: SPAN_KIND_INTERNAL
#       start_time_unix_nano: 1730002534906317780
#       end_time_unix_nano: 1730002534907852876
#       attributes {
#         key: "app.recommendation.cache_enabled"
#         value {
#           bool_value: false
#         }
#       }
#       attributes {
#         key: "app.products.count"
#         value {
#           int_value: 10
#         }
#       }
#       attributes {
#         key: "app.filtered_products.count"
#         value {
#           int_value: 9
#         }
#       }
#       attributes {
#         key: "app.filtered_products.list"
#         value {
#           array_value {
#             values {
#               string_value: "1YMWWN1N4O"
#             }
#             values {
#               string_value: "HQTGWGPNH4"
#             }
#             values {
#               string_value: "2ZYFJ3GM2N"
#             }
#             values {
#               string_value: "9SIQT8TOJO"
#             }
#             values {
#               string_value: "6E92ZMYYFZ"
#             }
#           }
#         }
#       }
#       events {
#         time_unix_nano: 1730002534907154016
#         name: "feature_flag"
#         attributes {
#           key: "feature_flag.key"
#           value {
#             string_value: "recommendationServiceCacheFailure"
#           }
#         }
#         attributes {
#           key: "feature_flag.variant"
#           value {
#             string_value: "off"
#           }
#         }
#         attributes {
#           key: "feature_flag.provider_name"
#           value {
#             string_value: "FlagdProvider"
#           }
#         }
#       }
#       status {
#       }
#     }
#   }
# }
# resource_spans {
#   resource {
#     attributes {
#       key: "host.name"
#       value {
#         string_value: "otel-demo-flagd-8544848569-24jgr"
#       }
#     }
#     attributes {
#       key: "os.description"
#       value {
#         string_value: "Debian GNU/Linux Debian GNU/Linux 12 (bookworm) (Linux otel-demo-flagd-8544848569-24jgr 6.1.106-1-MANJARO #1 SMP PREEMPT_DYNAMIC Mon Aug 19 10:07:05 UTC 2024 x86_64)"
#       }
#     }
#     attributes {
#       key: "os.type"
#       value {
#         string_value: "linux"
#       }
#     }
#     attributes {
#       key: "process.runtime.version"
#       value {
#         string_value: "go1.22.5"
#       }
#     }
#     attributes {
#       key: "service.namespace"
#       value {
#         string_value: "opentelemetry-demo"
#       }
#     }
#     attributes {
#       key: "service.version"
#       value {
#         string_value: "v0.11.1"
#       }
#     }
#     attributes {
#       key: "telemetry.sdk.language"
#       value {
#         string_value: "go"
#       }
#     }
#     attributes {
#       key: "telemetry.sdk.name"
#       value {
#         string_value: "opentelemetry"
#       }
#     }
#     attributes {
#       key: "telemetry.sdk.version"
#       value {
#         string_value: "1.28.0"
#       }
#     }
#     attributes {
#       key: "service.name"
#       value {
#         string_value: "flagd"
#       }
#     }
#   }
#   scope_spans {
#     scope {
#       name: "connectrpc.com/otelconnect"
#       version: "semver:0.6.0-dev"
#     }
#     spans {
#       trace_id: "\004~\323~\270\227\2315\276\215!\251\r)\372\336"
#       span_id: "s\222I(+\\\374\t"
#       parent_span_id: "\344i\3660\315>\233\271"
#       name: "schema.v1.Service/ResolveBoolean"
#       kind: SPAN_KIND_SERVER
#       start_time_unix_nano: 1730002534906801123
#       end_time_unix_nano: 1730002534906848292
#       attributes {
#         key: "net.peer.name"
#         value {
#           string_value: "10.244.0.96"
#         }
#       }
#       attributes {
#         key: "net.peer.port"
#         value {
#           int_value: 49666
#         }
#       }
#       attributes {
#         key: "rpc.system"
#         value {
#           string_value: "grpc"
#         }
#       }
#       attributes {
#         key: "rpc.service"
#         value {
#           string_value: "schema.v1.Service"
#         }
#       }
#       attributes {
#         key: "rpc.method"
#         value {
#           string_value: "ResolveBoolean"
#         }
#       }
#       attributes {
#         key: "rpc.grpc.status_code"
#         value {
#           int_value: 0
#         }
#       }
#       events {
#         time_unix_nano: 1730002534906819291
#         name: "message"
#         attributes {
#           key: "message.type"
#           value {
#             string_value: "RECEIVED"
#           }
#         }
#         attributes {
#           key: "message.id"
#           value {
#             int_value: 1
#           }
#         }
#         attributes {
#           key: "message.uncompressed_size"
#           value {
#             int_value: 57
#           }
#         }
#       }
#       events {
#         time_unix_nano: 1730002534906843498
#         name: "message"
#         attributes {
#           key: "message.type"
#           value {
#             string_value: "SENT"
#           }
#         }
#         attributes {
#           key: "message.id"
#           value {
#             int_value: 1
#           }
#         }
#         attributes {
#           key: "message.uncompressed_size"
#           value {
#             int_value: 15
#           }
#         }
#       }
#       status {
#       }
#     }
#   }
# }
# resource_spans {
#   resource {
#     attributes {
#       key: "host.name"
#       value {
#         string_value: "otel-demo-flagd-8544848569-24jgr"
#       }
#     }
#     attributes {
#       key: "os.description"
#       value {
#         string_value: "Debian GNU/Linux Debian GNU/Linux 12 (bookworm) (Linux otel-demo-flagd-8544848569-24jgr 6.1.106-1-MANJARO #1 SMP PREEMPT_DYNAMIC Mon Aug 19 10:07:05 UTC 2024 x86_64)"
#       }
#     }
#     attributes {
#       key: "os.type"
#       value {
#         string_value: "linux"
#       }
#     }
#     attributes {
#       key: "process.runtime.version"
#       value {
#         string_value: "go1.22.5"
#       }
#     }
#     attributes {
#       key: "service.namespace"
#       value {
#         string_value: "opentelemetry-demo"
#       }
#     }
#     attributes {
#       key: "service.version"
#       value {
#         string_value: "v0.11.1"
#       }
#     }
#     attributes {
#       key: "telemetry.sdk.language"
#       value {
#         string_value: "go"
#       }
#     }
#     attributes {
#       key: "telemetry.sdk.name"
#       value {
#         string_value: "opentelemetry"
#       }
#     }
#     attributes {
#       key: "telemetry.sdk.version"
#       value {
#         string_value: "1.28.0"
#       }
#     }
#     attributes {
#       key: "service.name"
#       value {
#         string_value: "flagd"
#       }
#     }
#   }
#   scope_spans {
#     scope {
#       name: "flagEvaluationService"
#     }
#     spans {
#       trace_id: "\004~\323~\270\227\2315\276\215!\251\r)\372\336"
#       span_id: "\001\227W\231FIa\236"
#       parent_span_id: "s\222I(+\\\374\t"
#       name: "resolveBoolean"
#       kind: SPAN_KIND_SERVER
#       start_time_unix_nano: 1730002534906821332
#       end_time_unix_nano: 1730002534906839198
#       attributes {
#         key: "feature_flag.key"
#         value {
#           string_value: "recommendationServiceCacheFailure"
#         }
#       }
#       attributes {
#         key: "feature_flag.variant"
#         value {
#           string_value: "off"
#         }
#       }
#       attributes {
#         key: "feature_flag.provider_name"
#         value {
#           string_value: "flagd"
#         }
#       }
#       status {
#       }
#     }
#   }
# }
# resource_spans {
#   resource {
#     attributes {
#       key: "host.name"
#       value {
#         string_value: "otel-demo-flagd-8544848569-24jgr"
#       }
#     }
#     attributes {
#       key: "os.description"
#       value {
#         string_value: "Debian GNU/Linux Debian GNU/Linux 12 (bookworm) (Linux otel-demo-flagd-8544848569-24jgr 6.1.106-1-MANJARO #1 SMP PREEMPT_DYNAMIC Mon Aug 19 10:07:05 UTC 2024 x86_64)"
#       }
#     }
#     attributes {
#       key: "os.type"
#       value {
#         string_value: "linux"
#       }
#     }
#     attributes {
#       key: "process.runtime.version"
#       value {
#         string_value: "go1.22.5"
#       }
#     }
#     attributes {
#       key: "service.namespace"
#       value {
#         string_value: "opentelemetry-demo"
#       }
#     }
#     attributes {
#       key: "service.version"
#       value {
#         string_value: "v0.11.1"
#       }
#     }
#     attributes {
#       key: "telemetry.sdk.language"
#       value {
#         string_value: "go"
#       }
#     }
#     attributes {
#       key: "telemetry.sdk.name"
#       value {
#         string_value: "opentelemetry"
#       }
#     }
#     attributes {
#       key: "telemetry.sdk.version"
#       value {
#         string_value: "1.28.0"
#       }
#     }
#     attributes {
#       key: "service.name"
#       value {
#         string_value: "flagd"
#       }
#     }
#   }
#   scope_spans {
#     scope {
#       name: "jsonEvaluator"
#     }
#     spans {
#       trace_id: "\004~\323~\270\227\2315\276\215!\251\r)\372\336"
#       span_id: "\313&\301\372\235J\372\r"
#       parent_span_id: "\001\227W\231FIa\236"
#       name: "resolveBoolean"
#       kind: SPAN_KIND_INTERNAL
#       start_time_unix_nano: 1730002534906824747
#       end_time_unix_nano: 1730002534906828305
#       status {
#       }
#     }
#   }
# }
# resource_spans {
#   resource {
#     attributes {
#       key: "host.name"
#       value {
#         string_value: "otel-demo-productcatalogservice-74b85c94c8-hmb7c"
#       }
#     }
#     attributes {
#       key: "os.description"
#       value {
#         string_value: "Alpine Linux 3.20.2 (Linux otel-demo-productcatalogservice-74b85c94c8-hmb7c 6.1.106-1-MANJARO #1 SMP PREEMPT_DYNAMIC Mon Aug 19 10:07:05 UTC 2024 x86_64)"
#       }
#     }
#     attributes {
#       key: "os.type"
#       value {
#         string_value: "linux"
#       }
#     }
#     attributes {
#       key: "process.command_args"
#       value {
#         array_value {
#           values {
#             string_value: "./productcatalogservice"
#           }
#         }
#       }
#     }
#     attributes {
#       key: "process.executable.name"
#       value {
#         string_value: "productcatalogservice"
#       }
#     }
#     attributes {
#       key: "process.executable.path"
#       value {
#         string_value: "/usr/src/app/productcatalogservice"
#       }
#     }
#     attributes {
#       key: "process.owner"
#       value {
#         string_value: "root"
#       }
#     }
#     attributes {
#       key: "process.pid"
#       value {
#         int_value: 1
#       }
#     }
#     attributes {
#       key: "process.runtime.description"
#       value {
#         string_value: "go version go1.22.5 linux/amd64"
#       }
#     }
#     attributes {
#       key: "process.runtime.name"
#       value {
#         string_value: "go"
#       }
#     }
#     attributes {
#       key: "process.runtime.version"
#       value {
#         string_value: "go1.22.5"
#       }
#     }
#     attributes {
#       key: "service.namespace"
#       value {
#         string_value: "opentelemetry-demo"
#       }
#     }
#     attributes {
#       key: "service.version"
#       value {
#         string_value: "1.11.1"
#       }
#     }
#     attributes {
#       key: "telemetry.sdk.language"
#       value {
#         string_value: "go"
#       }
#     }
#     attributes {
#       key: "telemetry.sdk.name"
#       value {
#         string_value: "opentelemetry"
#       }
#     }
#     attributes {
#       key: "telemetry.sdk.version"
#       value {
#         string_value: "1.27.0"
#       }
#     }
#     attributes {
#       key: "service.name"
#       value {
#         string_value: "productcatalogservice"
#       }
#     }
#   }
#   scope_spans {
#     scope {
#       name: "go.opentelemetry.io/contrib/instrumentation/google.golang.org/grpc/otelgrpc"
#       version: "0.52.0"
#     }
#     spans {
#       trace_id: "\004~\323~\270\227\2315\276\215!\251\r)\372\336"
#       span_id: "\271\277\\\204\227\323\321\276"
#       parent_span_id: "\0214\230(43\342\234"
#       name: "oteldemo.ProductCatalogService/ListProducts"
#       kind: SPAN_KIND_SERVER
#       start_time_unix_nano: 1730002534907405565
#       end_time_unix_nano: 1730002534907459445
#       attributes {
#         key: "rpc.service"
#         value {
#           string_value: "oteldemo.ProductCatalogService"
#         }
#       }
#       attributes {
#         key: "rpc.method"
#         value {
#           string_value: "ListProducts"
#         }
#       }
#       attributes {
#         key: "rpc.system"
#         value {
#           string_value: "grpc"
#         }
#       }
#       attributes {
#         key: "app.products.count"
#         value {
#           int_value: 10
#         }
#       }
#       attributes {
#         key: "net.sock.peer.addr"
#         value {
#           string_value: "10.244.0.96"
#         }
#       }
#       attributes {
#         key: "net.sock.peer.port"
#         value {
#           int_value: 49798
#         }
#       }
#       attributes {
#         key: "rpc.grpc.status_code"
#         value {
#           int_value: 0
#         }
#       }
#       status {
#       }
#     }
#     spans {
#       trace_id: "\004~\323~\270\227\2315\276\215!\251\r)\372\336"
#       span_id: "OA`\023s\204\334\246"
#       parent_span_id: "\\\006\000c\030\315O\341"
#       name: "oteldemo.ProductCatalogService/GetProduct"
#       kind: SPAN_KIND_SERVER
#       start_time_unix_nano: 1730002534909045524
#       end_time_unix_nano: 1730002534909093978
#       attributes {
#         key: "rpc.service"
#         value {
#           string_value: "oteldemo.ProductCatalogService"
#         }
#       }
#       attributes {
#         key: "rpc.method"
#         value {
#           string_value: "GetProduct"
#         }
#       }
#       attributes {
#         key: "rpc.system"
#         value {
#           string_value: "grpc"
#         }
#       }
#       attributes {
#         key: "app.product.id"
#         value {
#           string_value: "1YMWWN1N4O"
#         }
#       }
#       attributes {
#         key: "app.product.name"
#         value {
#           string_value: "Eclipsmart Travel Refractor Telescope"
#         }
#       }
#       attributes {
#         key: "net.sock.peer.addr"
#         value {
#           string_value: "10.244.0.92"
#         }
#       }
#       attributes {
#         key: "net.sock.peer.port"
#         value {
#           int_value: 47950
#         }
#       }
#       attributes {
#         key: "rpc.grpc.status_code"
#         value {
#           int_value: 0
#         }
#       }
#       events {
#         time_unix_nano: 1730002534909079250
#         name: "Product Found - ID: 1YMWWN1N4O, Name: Eclipsmart Travel Refractor Telescope"
#       }
#       status {
#       }
#     }
#     spans {
#       trace_id: "\004~\323~\270\227\2315\276\215!\251\r)\372\336"
#       span_id: "\211n\276U\321\n\350\223"
#       parent_span_id: ":\234\350\374\020\020&d"
#       name: "oteldemo.ProductCatalogService/GetProduct"
#       kind: SPAN_KIND_SERVER
#       start_time_unix_nano: 1730002534909079246
#       end_time_unix_nano: 1730002534909110464
#       attributes {
#         key: "rpc.service"
#         value {
#           string_value: "oteldemo.ProductCatalogService"
#         }
#       }
#       attributes {
#         key: "rpc.method"
#         value {
#           string_value: "GetProduct"
#         }
#       }
#       attributes {
#         key: "rpc.system"
#         value {
#           string_value: "grpc"
#         }
#       }
#       attributes {
#         key: "app.product.id"
#         value {
#           string_value: "HQTGWGPNH4"
#         }
#       }
#       attributes {
#         key: "app.product.name"
#         value {
#           string_value: "The Comet Book"
#         }
#       }
#       attributes {
#         key: "net.sock.peer.addr"
#         value {
#           string_value: "10.244.0.92"
#         }
#       }
#       attributes {
#         key: "net.sock.peer.port"
#         value {
#           int_value: 47950
#         }
#       }
#       attributes {
#         key: "rpc.grpc.status_code"
#         value {
#           int_value: 0
#         }
#       }
#       events {
#         time_unix_nano: 1730002534909099244
#         name: "Product Found - ID: HQTGWGPNH4, Name: The Comet Book"
#       }
#       status {
#       }
#     }
#     spans {
#       trace_id: "\004~\323~\270\227\2315\276\215!\251\r)\372\336"
#       span_id: "G\272T\027\\\237\354l"
#       parent_span_id: "\317\355\210\031|\037\202q"
#       name: "oteldemo.ProductCatalogService/GetProduct"
#       kind: SPAN_KIND_SERVER
#       start_time_unix_nano: 1730002534909080845
#       end_time_unix_nano: 1730002534909121052
#       attributes {
#         key: "rpc.service"
#         value {
#           string_value: "oteldemo.ProductCatalogService"
#         }
#       }
#       attributes {
#         key: "rpc.method"
#         value {
#           string_value: "GetProduct"
#         }
#       }
#       attributes {
#         key: "rpc.system"
#         value {
#           string_value: "grpc"
#         }
#       }
#       attributes {
#         key: "app.product.id"
#         value {
#           string_value: "9SIQT8TOJO"
#         }
#       }
#       attributes {
#         key: "app.product.name"
#         value {
#           string_value: "Optical Tube Assembly"
#         }
#       }
#       attributes {
#         key: "net.sock.peer.addr"
#         value {
#           string_value: "10.244.0.92"
#         }
#       }
#       attributes {
#         key: "net.sock.peer.port"
#         value {
#           int_value: 47950
#         }
#       }
#       attributes {
#         key: "rpc.grpc.status_code"
#         value {
#           int_value: 0
#         }
#       }
#       events {
#         time_unix_nano: 1730002534909104095
#         name: "Product Found - ID: 9SIQT8TOJO, Name: Optical Tube Assembly"
#       }
#       status {
#       }
#     }
#     spans {
#       trace_id: "\004~\323~\270\227\2315\276\215!\251\r)\372\336"
#       span_id: "3\215\247\033TH\277\010"
#       parent_span_id: "HY<\305\213?\303\246"
#       name: "oteldemo.ProductCatalogService/GetProduct"
#       kind: SPAN_KIND_SERVER
#       start_time_unix_nano: 1730002534909112381
#       end_time_unix_nano: 1730002534909128861
#       attributes {
#         key: "rpc.service"
#         value {
#           string_value: "oteldemo.ProductCatalogService"
#         }
#       }
#       attributes {
#         key: "rpc.method"
#         value {
#           string_value: "GetProduct"
#         }
#       }
#       attributes {
#         key: "rpc.system"
#         value {
#           string_value: "grpc"
#         }
#       }
#       attributes {
#         key: "app.product.id"
#         value {
#           string_value: "2ZYFJ3GM2N"
#         }
#       }
#       attributes {
#         key: "app.product.name"
#         value {
#           string_value: "Roof Binoculars"
#         }
#       }
#       attributes {
#         key: "net.sock.peer.addr"
#         value {
#           string_value: "10.244.0.92"
#         }
#       }
#       attributes {
#         key: "net.sock.peer.port"
#         value {
#           int_value: 47950
#         }
#       }
#       attributes {
#         key: "rpc.grpc.status_code"
#         value {
#           int_value: 0
#         }
#       }
#       events {
#         time_unix_nano: 1730002534909122192
#         name: "Product Found - ID: 2ZYFJ3GM2N, Name: Roof Binoculars"
#       }
#       status {
#       }
#     }
#   }
# }

# %% [markdown]
# ## Model the trace

# %%
from google.protobuf.json_format import MessageToDict

attr_keys = ('string_value', 'int_value', 'double_value', 'bool_value')

spans = []

for resource_span in trace.resource_spans:
    # comprehension to extract resource attributes
    # transform attribute keys to snake_case where attribute key is a dot-separated string
    resource_attributes = {attr.key.replace('.', '_'): getattr(attr.value, key) 
                            for attr in resource_span.resource.attributes 
                            for key in attr_keys 
                            if attr.value.HasField(key)}


    for scope_span in resource_span.scope_spans:
        scope = scope_span.scope
        scope_name = scope.name
        scope_version = scope.version

        for span in scope_span.spans:

            # Convert span protobuf message to a dictionary
            span_dict = MessageToDict(span, preserving_proto_field_name=True)
            
            # Add resource-level attributes to the span data (e.g., service.name)
            span_dict.update(resource_attributes)
            
            # Add scope name and version
            span_dict['scope_name'] = scope_name
            span_dict['scope_version'] = scope_version

            spans.append(Span.from_dict(span_dict))


trace = Trace(trace_id, spans)

trace.to_df()
# Out:
#                     trace_id       span_id  \
# 0   BH7TfriXmTW+jSGpDSn63g==  aKvAVd/4GMI=
# 1   BH7TfriXmTW+jSGpDSn63g==  gFF/TVfW/Oc=
# 2   BH7TfriXmTW+jSGpDSn63g==  zSHmCbKi2Vw=
# 3   BH7TfriXmTW+jSGpDSn63g==  FkjlpwGzvEc=
# 4   BH7TfriXmTW+jSGpDSn63g==  MOQVzoPC58k=
# 5   BH7TfriXmTW+jSGpDSn63g==  5lraquDgfQo=
# 6   BH7TfriXmTW+jSGpDSn63g==  2epZvrRX/Ro=
# 7   BH7TfriXmTW+jSGpDSn63g==  Opzo/BAQJmQ=
# 8   BH7TfriXmTW+jSGpDSn63g==  SFk8xYs/w6Y=
# 9   BH7TfriXmTW+jSGpDSn63g==  XAYAYxjNT+E=
# 10  BH7TfriXmTW+jSGpDSn63g==  z+2IGXwfgnE=
# 11  BH7TfriXmTW+jSGpDSn63g==  DGgJR03BoAk=
# 12  BH7TfriXmTW+jSGpDSn63g==  5Gn2MM0+m7k=
# 13  BH7TfriXmTW+jSGpDSn63g==  ETSYKDQz4pw=
# 14  BH7TfriXmTW+jSGpDSn63g==  v58i2UHfGE4=
# 15  BH7TfriXmTW+jSGpDSn63g==  c5JJKCtc/Ak=
# 16  BH7TfriXmTW+jSGpDSn63g==  AZdXmUZJYZ4=
# 17  BH7TfriXmTW+jSGpDSn63g==  yybB+p1K+g0=
# 18  BH7TfriXmTW+jSGpDSn63g==  ub9chJfT0b4=
# 19  BH7TfriXmTW+jSGpDSn63g==  T0FgE3OE3KY=
# 20  BH7TfriXmTW+jSGpDSn63g==  iW6+VdEK6JM=
# 21  BH7TfriXmTW+jSGpDSn63g==  R7pUF1yf7Gw=
# 22  BH7TfriXmTW+jSGpDSn63g==  M42nG1RIvwg=
#
#                                                  name                kind  \
# 0                                                 GET    SPAN_KIND_CLIENT
# 1                                                 GET    SPAN_KIND_SERVER
# 2                                             ingress    SPAN_KIND_SERVER
# 3                              router frontend egress    SPAN_KIND_CLIENT
# 4      GET /api/recommendations?productIds=66VCHSJNUP    SPAN_KIND_SERVER
# 5    executing api route (pages) /api/recommendations  SPAN_KIND_INTERNAL
# 6   grpc.oteldemo.RecommendationService/ListRecomm...    SPAN_KIND_CLIENT
# 7      grpc.oteldemo.ProductCatalogService/GetProduct    SPAN_KIND_CLIENT
# 8      grpc.oteldemo.ProductCatalogService/GetProduct    SPAN_KIND_CLIENT
# 9      grpc.oteldemo.ProductCatalogService/GetProduct    SPAN_KIND_CLIENT
# 10     grpc.oteldemo.ProductCatalogService/GetProduct    SPAN_KIND_CLIENT
# 11  /oteldemo.RecommendationService/ListRecommenda...    SPAN_KIND_SERVER
# 12                  /schema.v1.Service/ResolveBoolean    SPAN_KIND_CLIENT
# 13       /oteldemo.ProductCatalogService/ListProducts    SPAN_KIND_CLIENT
# 14                                   get_product_list  SPAN_KIND_INTERNAL
# 15                   schema.v1.Service/ResolveBoolean    SPAN_KIND_SERVER
# 16                                     resolveBoolean    SPAN_KIND_SERVER
# 17                                     resolveBoolean  SPAN_KIND_INTERNAL
# 18        oteldemo.ProductCatalogService/ListProducts    SPAN_KIND_SERVER
# 19          oteldemo.ProductCatalogService/GetProduct    SPAN_KIND_SERVER
# 20          oteldemo.ProductCatalogService/GetProduct    SPAN_KIND_SERVER
# 21          oteldemo.ProductCatalogService/GetProduct    SPAN_KIND_SERVER
# 22          oteldemo.ProductCatalogService/GetProduct    SPAN_KIND_SERVER
#
#    start_time_unix_nano   end_time_unix_nano  \
# 0   1730002534903897570  1730002534911258581
# 1   1730002534904000000  1730002534909618453
# 2   1730002534904568000  1730002534910532000
# 3   1730002534904662000  1730002534910505000
# 4   1730002534905000000  1730002534909727600
# 5   1730002534905000000  1730002534909474036
# 6   1730002534905000000  1730002534907906271
# 7   1730002534908000000  1730002534908942814
# 8   1730002534908000000  1730002534909073175
# 9   1730002534908000000  1730002534908942665
# 10  1730002534908000000  1730002534908921675
# 11  1730002534906285769  1730002534907991156
# 12  1730002534906444824  1730002534907109541
# 13  1730002534907210495  1730002534907810199
# 14  1730002534906317780  1730002534907852876
# 15  1730002534906801123  1730002534906848292
# 16  1730002534906821332  1730002534906839198
# 17  1730002534906824747  1730002534906828305
# 18  1730002534907405565  1730002534907459445
# 19  1730002534909045524  1730002534909093978
# 20  1730002534909079246  1730002534909110464
# 21  1730002534909080845  1730002534909121052
# 22  1730002534909112381  1730002534909128861
#
#                                            attributes status  \
# 0   [{'key': 'http.method', 'value': {'string_valu...     {}
# 1   [{'key': 'http.host', 'value': {'string_value'...     {}
# 2   [{'key': 'node_id', 'value': {'string_value': ...     {}
# 3   [{'key': 'http.protocol', 'value': {'string_va...     {}
# 4   [{'key': 'next.span_name', 'value': {'string_v...     {}
# 5   [{'key': 'next.span_name', 'value': {'string_v...     {}
# 6   [{'key': 'rpc.system', 'value': {'string_value...     {}
# 7   [{'key': 'rpc.system', 'value': {'string_value...     {}
# 8   [{'key': 'rpc.system', 'value': {'string_value...     {}
# 9   [{'key': 'rpc.system', 'value': {'string_value...     {}
# 10  [{'key': 'rpc.system', 'value': {'string_value...     {}
# 11  [{'key': 'rpc.system', 'value': {'string_value...     {}
# 12  [{'key': 'rpc.system', 'value': {'string_value...     {}
# 13  [{'key': 'rpc.system', 'value': {'string_value...     {}
# 14  [{'key': 'app.recommendation.cache_enabled', '...     {}
# 15  [{'key': 'net.peer.name', 'value': {'string_va...     {}
# 16  [{'key': 'feature_flag.key', 'value': {'string...     {}
# 17                                                NaN     {}
# 18  [{'key': 'rpc.service', 'value': {'string_valu...     {}
# 19  [{'key': 'rpc.service', 'value': {'string_valu...     {}
# 20  [{'key': 'rpc.service', 'value': {'string_valu...     {}
# 21  [{'key': 'rpc.service', 'value': {'string_valu...     {}
# 22  [{'key': 'rpc.service', 'value': {'string_valu...     {}
#
#    telemetry_sdk_language telemetry_sdk_name  ... process_executable_name  \
# 0                  python      opentelemetry  ...                     NaN
# 1                  nodejs      opentelemetry  ...                    node
# 2                     NaN                NaN  ...                     NaN
# 3                     NaN                NaN  ...                     NaN
# 4                  nodejs      opentelemetry  ...                    node
# 5                  nodejs      opentelemetry  ...                    node
# 6                  nodejs      opentelemetry  ...                    node
# 7                  nodejs      opentelemetry  ...                    node
# 8                  nodejs      opentelemetry  ...                    node
# 9                  nodejs      opentelemetry  ...                    node
# 10                 nodejs      opentelemetry  ...                    node
# 11                 python      opentelemetry  ...                     NaN
# 12                 python      opentelemetry  ...                     NaN
# 13                 python      opentelemetry  ...                     NaN
# 14                 python      opentelemetry  ...                     NaN
# 15                     go      opentelemetry  ...                     NaN
# 16                     go      opentelemetry  ...                     NaN
# 17                     go      opentelemetry  ...                     NaN
# 18                     go      opentelemetry  ...   productcatalogservice
# 19                     go      opentelemetry  ...   productcatalogservice
# 20                     go      opentelemetry  ...   productcatalogservice
# 21                     go      opentelemetry  ...   productcatalogservice
# 22                     go      opentelemetry  ...   productcatalogservice
#
#                process_executable_path process_runtime_version  \
# 0                                  NaN                     NaN
# 1                  /usr/local/bin/node                 20.16.0
# 2                                  NaN                     NaN
# 3                                  NaN                     NaN
# 4                  /usr/local/bin/node                 20.16.0
# 5                  /usr/local/bin/node                 20.16.0
# 6                  /usr/local/bin/node                 20.16.0
# 7                  /usr/local/bin/node                 20.16.0
# 8                  /usr/local/bin/node                 20.16.0
# 9                  /usr/local/bin/node                 20.16.0
# 10                 /usr/local/bin/node                 20.16.0
# 11                                 NaN                     NaN
# 12                                 NaN                     NaN
# 13                                 NaN                     NaN
# 14                                 NaN                     NaN
# 15                                 NaN                go1.22.5
# 16                                 NaN                go1.22.5
# 17                                 NaN                go1.22.5
# 18  /usr/src/app/productcatalogservice                go1.22.5
# 19  /usr/src/app/productcatalogservice                go1.22.5
# 20  /usr/src/app/productcatalogservice                go1.22.5
# 21  /usr/src/app/productcatalogservice                go1.22.5
# 22  /usr/src/app/productcatalogservice                go1.22.5
#
#    process_runtime_name      process_runtime_description process_command  \
# 0                   NaN                              NaN             NaN
# 1                nodejs                          Node.js  /app/server.js
# 2                   NaN                              NaN             NaN
# 3                   NaN                              NaN             NaN
# 4                nodejs                          Node.js  /app/server.js
# 5                nodejs                          Node.js  /app/server.js
# 6                nodejs                          Node.js  /app/server.js
# 7                nodejs                          Node.js  /app/server.js
# 8                nodejs                          Node.js  /app/server.js
# 9                nodejs                          Node.js  /app/server.js
# 10               nodejs                          Node.js  /app/server.js
# 11                  NaN                              NaN             NaN
# 12                  NaN                              NaN             NaN
# 13                  NaN                              NaN             NaN
# 14                  NaN                              NaN             NaN
# 15                  NaN                              NaN             NaN
# 16                  NaN                              NaN             NaN
# 17                  NaN                              NaN             NaN
# 18                   go  go version go1.22.5 linux/amd64             NaN
# 19                   go  go version go1.22.5 linux/amd64             NaN
# 20                   go  go version go1.22.5 linux/amd64             NaN
# 21                   go  go version go1.22.5 linux/amd64             NaN
# 22                   go  go version go1.22.5 linux/amd64             NaN
#
#    process_owner telemetry_auto_version  \
# 0            NaN                    NaN
# 1         nextjs                    NaN
# 2            NaN                    NaN
# 3            NaN                    NaN
# 4         nextjs                    NaN
# 5         nextjs                    NaN
# 6         nextjs                    NaN
# 7         nextjs                    NaN
# 8         nextjs                    NaN
# 9         nextjs                    NaN
# 10        nextjs                    NaN
# 11           NaN                 0.46b0
# 12           NaN                 0.46b0
# 13           NaN                 0.46b0
# 14           NaN                 0.46b0
# 15           NaN                    NaN
# 16           NaN                    NaN
# 17           NaN                    NaN
# 18          root                    NaN
# 19          root                    NaN
# 20          root                    NaN
# 21          root                    NaN
# 22          root                    NaN
#
#                                                events  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  [{'time_unix_nano': '1730002534907154016', 'na...
# 15  [{'time_unix_nano': '1730002534906819291', 'na...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  [{'time_unix_nano': '1730002534909079250', 'na...
# 20  [{'time_unix_nano': '1730002534909099244', 'na...
# 21  [{'time_unix_nano': '1730002534909104095', 'na...
# 22  [{'time_unix_nano': '1730002534909122192', 'na...
#
#                                        os_description
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  Debian GNU/Linux Debian GNU/Linux 12 (bookworm...
# 16  Debian GNU/Linux Debian GNU/Linux 12 (bookworm...
# 17  Debian GNU/Linux Debian GNU/Linux 12 (bookworm...
# 18  Alpine Linux 3.20.2 (Linux otel-demo-productca...
# 19  Alpine Linux 3.20.2 (Linux otel-demo-productca...
# 20  Alpine Linux 3.20.2 (Linux otel-demo-productca...
# 21  Alpine Linux 3.20.2 (Linux otel-demo-productca...
# 22  Alpine Linux 3.20.2 (Linux otel-demo-productca...
#
# [23 rows x 33 columns]
