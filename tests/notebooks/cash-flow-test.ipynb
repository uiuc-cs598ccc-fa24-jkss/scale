# %% [markdown]
# ### Testing the cash-flow test cluster with the cash-flow cli tool
#
# Prerequisites:
# 1. You have a the cash-flow test cluster running on minikube
# 2. You've setup a python environment to execute the cash cli tool
# 3. You've run through the [Setup Doc](../../test-clusters/cash-flow/docs/Setup.md#to-run-the-full-setup)
#     * All you really need is to make sure the the `deploy.sh` script has been run to ensure the client apis have been generated.

# %% [markdown]
# ### Create python venv for cash flow command line tool and install it
#
# If you've already create this virtualenv, then make sure you are using that environment to execute this notebook.
# If you haven't, then run the following block and set your notebook to run with the new environment.

# %%
# !python -m venv cli
# !source cli/bin/activate  && pip install -r ../../test-clusters/cash-flow/cli/requirements.txt && deactivate
# !source cli/bin/activate  && pip install -r ../../test-clusters/cash-flow/backend/requirements.txt && deactivate
# !source cli/bin/activate  && pip install -e ../../test-clusters/cash-flow/cli && deactivate

# %% [markdown]
# ### Verify installation
#
# Make sure this notebook is set to use that environment, and test to verify the tool works

# %%
# !cash --help

# %% [markdown]
# ## Verify your minikube cluster is running
# See [Minikube setup](./minikube.ipynb)

# %%
# !kubectl get pods -n cash-flow

# %% [markdown]
# After running the block above, you should see output similar to this.
#
# ```bash
# auth-5fd84d4f95-5dk79             1/1     Running   0             28m
# celery-worker-7c98bc497f-8t5mk    1/1     Running   0             28m
# dms-57946db4f6-74zkg              1/1     Running   0             28m
# grafana-58c6666fc5-spzvr          1/1     Running   7 (46m ago)   116m
# notification-54898b9b49-svc8w     1/1     Running   0             28m
# otel-collector-6595d959cf-blv7r   1/1     Running   7 (46m ago)   116m
# redis-6664db5d7c-tx8dp            1/1     Running   0             28m
# registration-677864c8bf-cvb87     1/1     Running   0             28m
# tasking-5c96756555-f87ks          1/1     Running   0             28m
# tempo-859dbfff85-vx7z6            1/1     Running   7 (46m ago)   116m
# tlm-service-6c694ddc7c-p8qwh      1/1     Running   7 (46m ago)   116m
# transaction-647c77f96f-rmq2w      1/1     Running   0             28m
# tx-db-dep-5cb5b7b4d6-ssr77        1/1     Running   0             28m
# user-db-dep-76f5ff8cc7-hb8jn      1/1     Running   0             28m
# ```

# %% [markdown]
# ## Using the command line tool

# %%
# !cash sim
# Out:
# Service IP auth: http://192.168.49.2:30211
# Service IP dms: http://192.168.49.2:31826
# Service IP registration: http://192.168.49.2:31567
# Service IP tasking: http://192.168.49.2:30789
# Service IP transaction: http://192.168.49.2:31670
# Service IP redis: http://192.168.49.2:30978
# Creating user file: ./sim_users_2024-10-11_222631.json
# REDIS_HOST 192.168.49.2
# Code for janicehart@example.net: N0SRI2
# Code for kylemosley@example.org: C638IS
# Verification response: valid=TrueVerification response: valid=True
# Verified kylemosley@example.org
# Verified janicehart@example.net
#
# Code for kaneandrew@example.net: 257NU5
# Verification response: valid=True
# Verified kaneandrew@example.net
# ╭───────── Success ─────────╮
# │ User created successfully │
# ╰───────────────────────────╯
# ╭───────── Success ─────────╮
# │ User created successfully │
# ╰───────────────────────────╯
# ╭───────── Success ─────────╮
# │ User created successfully │
# ╰───────────────────────────╯
# Code for gregorycochran@example.com: 56KQUO
# Code for cynthiapena@example.com: PWMZCQ
# Verification response: valid=True
# Verified gregorycochran@example.com
# Code for bradleybrittany@example.net: 9B7ECX
# Verification response: valid=True
# Verified cynthiapena@example.com
# Verification response: valid=True
# Verified bradleybrittany@example.net
# ╭───────── Success ─────────╮
# │ User created successfully │
# ╰───────────────────────────╯
# ╭───────── Success ─────────╮
# │ User created successfully │
# ╰───────────────────────────╯
# ╭───────── Success ─────────╮
# │ User created successfully │
# ╰───────────────────────────╯
# Code for rhonda21@example.org: P5HDQC
# Code for scott50@example.net: 4MGRAB
# Code for jhess@example.net: JHHUVP
# Verification response: valid=True
# Verified rhonda21@example.org
# Verification response: valid=TrueVerification response: valid=True
#
# Verified jhess@example.net
# Verified scott50@example.net
# ╭───────── Success ─────────╮
# │ User created successfully │
# ╰───────────────────────────╯
# ╭───────── Success ─────────╮
# │ User created successfully │
# ╰───────────────────────────╯
# ╭───────── Success ─────────╮
# │ User created successfully │
# ╰───────────────────────────╯
# Code for john58@example.org: EV8TSI
# Verification response: valid=True
# Verified john58@example.org
# ╭───────── Success ─────────╮
# │ User created successfully │
# ╰───────────────────────────╯
# ╭──── Success ─────╮
# │ Login Successful │
# ╰──────────────────╯
# Creating transaction...
# ╭──── Success ─────╮
# │ Login Successful │
# ╰──────────────────╯
# Creating transaction...
# ╭──── Success ─────╮
# │ Login Successful │
# ╰──────────────────╯
# ╭──────────── Success ─────────────╮
# │ Transaction created successfully │
# ╰──────────────────────────────────╯
# Viewing transactions
# Creating transaction...
# ╭──────────── Success ─────────────╮
# │ Transaction created successfully │
# ╰──────────────────────────────────╯
# Viewing transactions
# [{'amount': 14.0, 'category': 'Fuel', 'description': 'State left collection have.', 'date': '2024-10-03T17:02:33.656106'}]
# Creating transaction...
# [{'amount': 875.0, 'category': 'Car Maintenance', 'description': 'Two unit good.', 'date': '2024-03-29T20:13:05.933180'}]╭──────────── Success ─────────────╮
# │ Transaction created successfully │
# ╰──────────────────────────────────╯
#
# Viewing transactions
# ╭──────────── Success ─────────────╮
# │ Transaction created successfully │
# ╰──────────────────────────────────╯
# Creating transaction...
# [{'amount': 206.0, 'category': 'Home Improvement', 'description': 'Star morning lay approach cultural often.', 'date': '2024-02-25T06:32:50.592185'}]
# Creating transaction...
# ╭──── Success ─────╮
# │ Login Successful │
# ╰──────────────────╯
# Creating transaction...
# ╭──────────── Success ─────────────╮
# │ Transaction created successfully │
# ╰──────────────────────────────────╯
# ╭──────────── Success ─────────────╮
# │ Transaction created successfully │
# ╰──────────────────────────────────╯
# ╭──── Success ─────╮
# │ Login Successful │
# ╰──────────────────╯
# Creating transaction...
# ╭──── Success ─────╮
# │ Login Successful │
# ╰──────────────────╯
# Creating transaction...
# ╭──────────── Success ─────────────╮
# │ Transaction created successfully │
# ╰──────────────────────────────────╯
# ╭──────────── Success ─────────────╮
# │ Transaction created successfully │
# ╰──────────────────────────────────╯
# Viewing transactions
# Viewing transactions
# ╭──────────── Success ─────────────╮
# │ Transaction created successfully │
# ╰──────────────────────────────────╯
# Viewing transactions
# [{'amount': 514.0, 'category': 'Travel', 'description': 'Evening claim perform.', 'date': '2024-02-24T07:29:56.717090'}][{'amount': 289.0, 'category': 'Subscriptions', 'description': 'Save tax heavy gas particular interesting education.', 'date': '2024-06-24T11:10:28.800287'}]
#
# [{'amount': 853.0, 'category': 'Restaurants', 'description': 'Magazine rest executive.', 'date': '2024-09-14T04:14:11.439813'}]
# Creating transaction...
# ╭──────────── Success ─────────────╮
# │ Transaction created successfully │
# ╰──────────────────────────────────╯
# Creating transaction...
# Creating transaction...
# ╭──── Success ─────╮
# │ Login Successful │
# ╰──────────────────╯
# Creating transaction...
# ╭──────────── Success ─────────────╮
# │ Transaction created successfully │
# ╰──────────────────────────────────╯
# ╭──────────── Success ─────────────╮
# │ Transaction created successfully │
# ╰──────────────────────────────────╯
# ╭──── Success ─────╮
# │ Login Successful │
# ╰──────────────────╯
# Creating transaction...
# ╭──── Success ─────╮
# │ Login Successful │
# ╰──────────────────╯
# ╭──────────── Success ─────────────╮
# │ Transaction created successfully │
# ╰──────────────────────────────────╯
# Viewing transactions
# Creating transaction...
# ╭──────────── Success ─────────────╮
# │ Transaction created successfully │
# ╰──────────────────────────────────╯
# Viewing transactions
# [{'amount': 218.0, 'category': 'Public Transport', 'description': 'Time team toward more meeting purpose.', 'date': '2024-01-19T08:32:15.763849'}]
# Creating transaction...
# ╭──────────── Success ─────────────╮
# │ Transaction created successfully │
# ╰──────────────────────────────────╯
# [{'amount': 739.0, 'category': 'Gifts', 'description': 'Pressure station play per bad letter.', 'date': '2024-01-23T04:58:19.574525'}]
# Viewing transactions
# ╭──────────── Success ─────────────╮
# │ Transaction created successfully │
# ╰──────────────────────────────────╯
# Creating transaction...
# [{'amount': 296.0, 'category': 'Travel', 'description': 'Model foot long.', 'date': '2024-01-10T19:36:41.015672'}]
# Creating transaction...
# ╭──── Success ─────╮
# │ Login Successful │
# ╰──────────────────╯
# Creating transaction...
# ╭──────────── Success ─────────────╮
# │ Transaction created successfully │
# ╰──────────────────────────────────╯
# ╭──────────── Success ─────────────╮
# │ Transaction created successfully │
# ╰──────────────────────────────────╯
# ╭──────────── Success ─────────────╮
# │ Transaction created successfully │
# ╰──────────────────────────────────╯
# Viewing transactions
# [{'amount': 573.0, 'category': 'Insurance', 'description': 'Picture consumer per these.', 'date': '2024-08-25T19:48:21.631321'}]
# Creating transaction...
# ╭──────────── Success ─────────────╮
# │ Transaction created successfully │
# ╰──────────────────────────────────╯

# %% [markdown]
# If you see successful transaction like the block below then the application is working and generating traces.
#
# ```bash
# Service IP auth: http://192.168.49.2:30822
# Service IP dms: http://192.168.49.2:30629
# Service IP registration: http://192.168.49.2:31758
# Service IP tasking: http://192.168.49.2:31070
# Service IP transaction: http://192.168.49.2:31420
# Service IP redis: http://192.168.49.2:31097
# Creating user file: ./sim_users_2024-10-10_202256.json
# REDIS_HOST 192.168.49.2
# ....
# ╭──────────── Success ─────────────╮
# │ Transaction created successfully │
# ╰──────────────────────────────────╯
# Viewing transactions
# [{'amount': 716.0, 'category': 'Utilities', 'description': 'Security once music born.', 'date': '2024-10-04T09:56:27.456134'}]
# [{'amount': 671.0, 'category': 'Subscriptions', 'description': 'Experience investment despite least far author.', 'date': '2024-04-07T09:19:06.392931'}]
# [{'amount': 4.0, 'category': 'Savings', 'description': 'Money attorney hundred standard avoid.', 'date': '2024-01-10T09:11:02.669539'}]
# Creating transaction...
# Creating transaction...
# Creating transaction...
# ╭──────────── Success ─────────────╮
# │ Transaction created successfully │
# ╰──────────────────────────────────╯
# ╭──────────── Success ─────────────╮
# │ Transaction created successfully │
# ╰──────────────────────────────────╯
# ```

# %% [markdown]
# ### Viewing traces

# %% [markdown]
# 1. To see how to pull the trace data from `tempo`, go to the [trace modeling notebook](./trace_modeling.ipynb)
#
# 2. To view traces in **grafana**, go to http://192.168.49.2:30000
#
#     * If you can't get to the ip above, you can use port-forwarding
#
#     **Note:** you'll need to run this command in a separate terminal and leave it running as long as you want access to the grafana UI
#
#     ```bash
#     kubectl port-forward svc/grafana 8080:3000 -n cash-flow
#     ```
#
#     You should now be able to access grafana at http://localhost:8080
#
# 3. View the `tlm-service` logs
#
#     **Note**: adjust the name of the `tlm-service` to the one in your cluster

# %%
# You probably don't want to execute either of the first two in the notebook

# View all of the logs
# !kubectl logs -n cash-flow tlm-service-6c694ddc7c-p8qwh

# Tail the logs
# !kubectl logs -n cash-flow tlm-service-6c694ddc7c-p8qwh --follow

# View the last 100 lines of the logs
# !kubectl logs -n cash-flow tlm-service-6c694ddc7c-p8qwh --tail 100
# Out:
# | 46  | 5F6N9F4CYbfbpyy/1VqPjQ== | UjLg0haoXnA= |      nan       |        POST /         |  SPAN_KIND_SERVER  | 1728707201042714704  | 1728707201071799824 |     [{'key': 'http.scheme', 'value': {'string_value': 'http'}}, {'key': 'http.host', 'value': {'string_value': '10.244.0.11:8000'}}, {'key': 'net.host.port', 'value': {'int_value': '8000'}}, {'key': 'http.flavor', 'value': {'string_value': '1.1'}}, {'key': 'http.target', 'value': {'string_value': '/api/v1/transactions/'}}, {'key': 'http.url', 'value': {'string_value': 'http://10.244.0.11:8000/api/v1/transactions/'}}, {'key': 'http.method', 'value': {'string_value': 'POST'}}, {'key': 'http.server_name', 'value': {'string_value': '192.168.49.2:31670'}}, {'key': 'http.user_agent', 'value': {'string_value': 'python-requests/2.32.3'}}, {'key': 'net.peer.ip', 'value': {'string_value': '10.244.0.1'}}, {'key': 'net.peer.port', 'value': {'int_value': '4292'}}, {'key': 'http.route', 'value': {'string_value': '/'}}, {'key': 'http.status_code', 'value': {'int_value': '200'}}]      |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 47  | Y/oV0vK2/quD47nfjEQdMQ== | ZAtLNhJbYmg= |  f+fH5qJiyyA=  |    GET / http send    | SPAN_KIND_INTERNAL | 1728707201090416144  | 1728707201090854624 |                                                                                                                                                                                                                                                                                                                                                                                    [{'key': 'asgi.event.type', 'value': {'string_value': 'http.response.start'}}, {'key': 'http.status_code', 'value': {'int_value': '200'}}]                                                                                                                                                                                                                                                                                                                                                                                     |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 48  | Y/oV0vK2/quD47nfjEQdMQ== | xrbEaOhfgdM= |  f+fH5qJiyyA=  |    GET / http send    | SPAN_KIND_INTERNAL | 1728707201091019504  | 1728707201091081244 |                                                                                                                                                                                                                                                                                                                                                                                                                   [{'key': 'asgi.event.type', 'value': {'string_value': 'http.response.body'}}]                                                                                                                                                                                                                                                                                                                                                                                                                   |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 49  | Y/oV0vK2/quD47nfjEQdMQ== | f+fH5qJiyyA= |      nan       |         GET /         |  SPAN_KIND_SERVER  | 1728707201048108134  | 1728707201091095374 |     [{'key': 'http.scheme', 'value': {'string_value': 'http'}}, {'key': 'http.host', 'value': {'string_value': '10.244.0.11:8000'}}, {'key': 'net.host.port', 'value': {'int_value': '8000'}}, {'key': 'http.flavor', 'value': {'string_value': '1.1'}}, {'key': 'http.target', 'value': {'string_value': '/api/v1/transactions/'}}, {'key': 'http.url', 'value': {'string_value': 'http://10.244.0.11:8000/api/v1/transactions/'}}, {'key': 'http.method', 'value': {'string_value': 'GET'}}, {'key': 'http.server_name', 'value': {'string_value': '192.168.49.2:31670'}}, {'key': 'http.user_agent', 'value': {'string_value': 'python-requests/2.32.3'}}, {'key': 'net.peer.ip', 'value': {'string_value': '10.244.0.1'}}, {'key': 'net.peer.port', 'value': {'int_value': '36705'}}, {'key': 'http.route', 'value': {'string_value': '/'}}, {'key': 'http.status_code', 'value': {'int_value': '200'}}]      |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 50  | Nz2I/ueyBRRbf3qNCJGMMA== | GBvBwdMbSHo= |  2QAJWNM61ZA=  |    GET / http send    | SPAN_KIND_INTERNAL | 1728707201097477994  | 1728707201097779404 |                                                                                                                                                                                                                                                                                                                                                                                    [{'key': 'asgi.event.type', 'value': {'string_value': 'http.response.start'}}, {'key': 'http.status_code', 'value': {'int_value': '200'}}]                                                                                                                                                                                                                                                                                                                                                                                     |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 51  | Nz2I/ueyBRRbf3qNCJGMMA== | PT/xC6sN/+4= |  2QAJWNM61ZA=  |    GET / http send    | SPAN_KIND_INTERNAL | 1728707201097892534  | 1728707201097976864 |                                                                                                                                                                                                                                                                                                                                                                                                                   [{'key': 'asgi.event.type', 'value': {'string_value': 'http.response.body'}}]                                                                                                                                                                                                                                                                                                                                                                                                                   |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 52  | Nz2I/ueyBRRbf3qNCJGMMA== | 2QAJWNM61ZA= |      nan       |         GET /         |  SPAN_KIND_SERVER  | 1728707201053888744  | 1728707201097996664 |     [{'key': 'http.scheme', 'value': {'string_value': 'http'}}, {'key': 'http.host', 'value': {'string_value': '10.244.0.11:8000'}}, {'key': 'net.host.port', 'value': {'int_value': '8000'}}, {'key': 'http.flavor', 'value': {'string_value': '1.1'}}, {'key': 'http.target', 'value': {'string_value': '/api/v1/transactions/'}}, {'key': 'http.url', 'value': {'string_value': 'http://10.244.0.11:8000/api/v1/transactions/'}}, {'key': 'http.method', 'value': {'string_value': 'GET'}}, {'key': 'http.server_name', 'value': {'string_value': '192.168.49.2:31670'}}, {'key': 'http.user_agent', 'value': {'string_value': 'python-requests/2.32.3'}}, {'key': 'net.peer.ip', 'value': {'string_value': '10.244.0.1'}}, {'key': 'net.peer.port', 'value': {'int_value': '15125'}}, {'key': 'http.route', 'value': {'string_value': '/'}}, {'key': 'http.status_code', 'value': {'int_value': '200'}}]      |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 53  | Fk/lxiVv0h3/1npeehqYXQ== | 8iNzr+MRW1g= |  3u4lzR27l1I=  |    GET / http send    | SPAN_KIND_INTERNAL | 1728707201118735634  | 1728707201119120564 |                                                                                                                                                                                                                                                                                                                                                                                    [{'key': 'asgi.event.type', 'value': {'string_value': 'http.response.start'}}, {'key': 'http.status_code', 'value': {'int_value': '200'}}]                                                                                                                                                                                                                                                                                                                                                                                     |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 54  | Fk/lxiVv0h3/1npeehqYXQ== | S1JLaAEQG3o= |  3u4lzR27l1I=  |    GET / http send    | SPAN_KIND_INTERNAL | 1728707201119278244  | 1728707201119376704 |                                                                                                                                                                                                                                                                                                                                                                                                                   [{'key': 'asgi.event.type', 'value': {'string_value': 'http.response.body'}}]                                                                                                                                                                                                                                                                                                                                                                                                                   |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 55  | Fk/lxiVv0h3/1npeehqYXQ== | 3u4lzR27l1I= |      nan       |         GET /         |  SPAN_KIND_SERVER  | 1728707201101242154  | 1728707201119409644 |      [{'key': 'http.scheme', 'value': {'string_value': 'http'}}, {'key': 'http.host', 'value': {'string_value': '10.244.0.11:8000'}}, {'key': 'net.host.port', 'value': {'int_value': '8000'}}, {'key': 'http.flavor', 'value': {'string_value': '1.1'}}, {'key': 'http.target', 'value': {'string_value': '/api/v1/transactions/'}}, {'key': 'http.url', 'value': {'string_value': 'http://10.244.0.11:8000/api/v1/transactions/'}}, {'key': 'http.method', 'value': {'string_value': 'GET'}}, {'key': 'http.server_name', 'value': {'string_value': '192.168.49.2:31670'}}, {'key': 'http.user_agent', 'value': {'string_value': 'python-requests/2.32.3'}}, {'key': 'net.peer.ip', 'value': {'string_value': '10.244.0.1'}}, {'key': 'net.peer.port', 'value': {'int_value': '7085'}}, {'key': 'http.route', 'value': {'string_value': '/'}}, {'key': 'http.status_code', 'value': {'int_value': '200'}}]      |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 56  | /S3beklh1VCDspYDWxcuzw== | wftlCSeLCbY= |  AFlGdjCdQwQ=  |  POST / http receive  | SPAN_KIND_INTERNAL | 1728707201268974254  | 1728707201269121314 |                                                                                                                                                                                                                                                                                                                                                                                                                      [{'key': 'asgi.event.type', 'value': {'string_value': 'http.request'}}]                                                                                                                                                                                                                                                                                                                                                                                                                      |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 57  | /S3beklh1VCDspYDWxcuzw== | bE2gC+nLcSk= |  AFlGdjCdQwQ=  |   POST / http send    | SPAN_KIND_INTERNAL | 1728707201286130414  | 1728707201286433894 |                                                                                                                                                                                                                                                                                                                                                                                    [{'key': 'asgi.event.type', 'value': {'string_value': 'http.response.start'}}, {'key': 'http.status_code', 'value': {'int_value': '200'}}]                                                                                                                                                                                                                                                                                                                                                                                     |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 58  | /S3beklh1VCDspYDWxcuzw== | jDFOkikE2xU= |  AFlGdjCdQwQ=  |   POST / http send    | SPAN_KIND_INTERNAL | 1728707201286531454  | 1728707201286598864 |                                                                                                                                                                                                                                                                                                                                                                                                                   [{'key': 'asgi.event.type', 'value': {'string_value': 'http.response.body'}}]                                                                                                                                                                                                                                                                                                                                                                                                                   |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 59  | /S3beklh1VCDspYDWxcuzw== | AFlGdjCdQwQ= |      nan       |        POST /         |  SPAN_KIND_SERVER  | 1728707201268701194  | 1728707201286616954 |     [{'key': 'http.scheme', 'value': {'string_value': 'http'}}, {'key': 'http.host', 'value': {'string_value': '10.244.0.11:8000'}}, {'key': 'net.host.port', 'value': {'int_value': '8000'}}, {'key': 'http.flavor', 'value': {'string_value': '1.1'}}, {'key': 'http.target', 'value': {'string_value': '/api/v1/transactions/'}}, {'key': 'http.url', 'value': {'string_value': 'http://10.244.0.11:8000/api/v1/transactions/'}}, {'key': 'http.method', 'value': {'string_value': 'POST'}}, {'key': 'http.server_name', 'value': {'string_value': '192.168.49.2:31670'}}, {'key': 'http.user_agent', 'value': {'string_value': 'python-requests/2.32.3'}}, {'key': 'net.peer.ip', 'value': {'string_value': '10.244.0.1'}}, {'key': 'net.peer.port', 'value': {'int_value': '65174'}}, {'key': 'http.route', 'value': {'string_value': '/'}}, {'key': 'http.status_code', 'value': {'int_value': '200'}}]     |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 60  | R574eVg0Trx5TA7Q0+Y9jg== | ogXatOwnj+s= |  iTH7WfFFAyA=  |  POST / http receive  | SPAN_KIND_INTERNAL | 1728707201307175204  | 1728707201307487954 |                                                                                                                                                                                                                                                                                                                                                                                                                      [{'key': 'asgi.event.type', 'value': {'string_value': 'http.request'}}]                                                                                                                                                                                                                                                                                                                                                                                                                      |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 61  | ysnH0tC7rk+rFwzV7b1NYA== | 4/L+WQQvIdQ= |  N7kGVUcl/tw=  |  POST / http receive  | SPAN_KIND_INTERNAL | 1728707201311125034  | 1728707201311227094 |                                                                                                                                                                                                                                                                                                                                                                                                                      [{'key': 'asgi.event.type', 'value': {'string_value': 'http.request'}}]                                                                                                                                                                                                                                                                                                                                                                                                                      |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 62  | ysnH0tC7rk+rFwzV7b1NYA== | T/6/ketsuRw= |  N7kGVUcl/tw=  |   POST / http send    | SPAN_KIND_INTERNAL | 1728707201816164984  | 1728707201816465944 |                                                                                                                                                                                                                                                                                                                                                                                    [{'key': 'asgi.event.type', 'value': {'string_value': 'http.response.start'}}, {'key': 'http.status_code', 'value': {'int_value': '200'}}]                                                                                                                                                                                                                                                                                                                                                                                     |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 63  | ysnH0tC7rk+rFwzV7b1NYA== | 5a3eCBaBnTc= |  N7kGVUcl/tw=  |   POST / http send    | SPAN_KIND_INTERNAL | 1728707201816625334  | 1728707201816716774 |                                                                                                                                                                                                                                                                                                                                                                                                                   [{'key': 'asgi.event.type', 'value': {'string_value': 'http.response.body'}}]                                                                                                                                                                                                                                                                                                                                                                                                                   |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 64  | ysnH0tC7rk+rFwzV7b1NYA== | N7kGVUcl/tw= |      nan       |        POST /         |  SPAN_KIND_SERVER  | 1728707201310853594  | 1728707201816736394 |     [{'key': 'http.scheme', 'value': {'string_value': 'http'}}, {'key': 'http.host', 'value': {'string_value': '10.244.0.11:8000'}}, {'key': 'net.host.port', 'value': {'int_value': '8000'}}, {'key': 'http.flavor', 'value': {'string_value': '1.1'}}, {'key': 'http.target', 'value': {'string_value': '/api/v1/transactions/'}}, {'key': 'http.url', 'value': {'string_value': 'http://10.244.0.11:8000/api/v1/transactions/'}}, {'key': 'http.method', 'value': {'string_value': 'POST'}}, {'key': 'http.server_name', 'value': {'string_value': '192.168.49.2:31670'}}, {'key': 'http.user_agent', 'value': {'string_value': 'python-requests/2.32.3'}}, {'key': 'net.peer.ip', 'value': {'string_value': '10.244.0.1'}}, {'key': 'net.peer.port', 'value': {'int_value': '55680'}}, {'key': 'http.route', 'value': {'string_value': '/'}}, {'key': 'http.status_code', 'value': {'int_value': '200'}}]     |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 65  | R574eVg0Trx5TA7Q0+Y9jg== | KetOb2ulWhY= |  iTH7WfFFAyA=  |   POST / http send    | SPAN_KIND_INTERNAL | 1728707201828975044  | 1728707201829369424 |                                                                                                                                                                                                                                                                                                                                                                                    [{'key': 'asgi.event.type', 'value': {'string_value': 'http.response.start'}}, {'key': 'http.status_code', 'value': {'int_value': '200'}}]                                                                                                                                                                                                                                                                                                                                                                                     |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 66  | R574eVg0Trx5TA7Q0+Y9jg== | jRluAMyBIl8= |  iTH7WfFFAyA=  |   POST / http send    | SPAN_KIND_INTERNAL | 1728707201829566254  | 1728707201829654724 |                                                                                                                                                                                                                                                                                                                                                                                                                   [{'key': 'asgi.event.type', 'value': {'string_value': 'http.response.body'}}]                                                                                                                                                                                                                                                                                                                                                                                                                   |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 67  | R574eVg0Trx5TA7Q0+Y9jg== | iTH7WfFFAyA= |      nan       |        POST /         |  SPAN_KIND_SERVER  | 1728707201306828074  | 1728707201829678304 |     [{'key': 'http.scheme', 'value': {'string_value': 'http'}}, {'key': 'http.host', 'value': {'string_value': '10.244.0.11:8000'}}, {'key': 'net.host.port', 'value': {'int_value': '8000'}}, {'key': 'http.flavor', 'value': {'string_value': '1.1'}}, {'key': 'http.target', 'value': {'string_value': '/api/v1/transactions/'}}, {'key': 'http.url', 'value': {'string_value': 'http://10.244.0.11:8000/api/v1/transactions/'}}, {'key': 'http.method', 'value': {'string_value': 'POST'}}, {'key': 'http.server_name', 'value': {'string_value': '192.168.49.2:31670'}}, {'key': 'http.user_agent', 'value': {'string_value': 'python-requests/2.32.3'}}, {'key': 'net.peer.ip', 'value': {'string_value': '10.244.0.1'}}, {'key': 'net.peer.port', 'value': {'int_value': '39899'}}, {'key': 'http.route', 'value': {'string_value': '/'}}, {'key': 'http.status_code', 'value': {'int_value': '200'}}]     |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 68  | 1q+91AiRaGY4lyuGsnv/yw== | cQSas8l0l+Y= |  5hRUp4YthEs=  |  POST / http receive  | SPAN_KIND_INTERNAL | 1728707201835661324  | 1728707201836136434 |                                                                                                                                                                                                                                                                                                                                                                                                                      [{'key': 'asgi.event.type', 'value': {'string_value': 'http.request'}}]                                                                                                                                                                                                                                                                                                                                                                                                                      |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 69  | nG01YZoWtO0eJYhtVTOvvQ== | DlnMrvrCQqY= |  VOBWMBTCynY=  |  POST / http receive  | SPAN_KIND_INTERNAL | 1728707202354618154  | 1728707202354643894 |                                                                                                                                                                                                                                                                                                                                                                                                                      [{'key': 'asgi.event.type', 'value': {'string_value': 'http.request'}}]                                                                                                                                                                                                                                                                                                                                                                                                                      |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 70  | nG01YZoWtO0eJYhtVTOvvQ== | 3k/bmImIvoU= |  VOBWMBTCynY=  |   POST / http send    | SPAN_KIND_INTERNAL | 1728707202837531154  | 1728707202837870634 |                                                                                                                                                                                                                                                                                                                                                                                    [{'key': 'asgi.event.type', 'value': {'string_value': 'http.response.start'}}, {'key': 'http.status_code', 'value': {'int_value': '200'}}]                                                                                                                                                                                                                                                                                                                                                                                     |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 71  | nG01YZoWtO0eJYhtVTOvvQ== | DKWhooNcCDI= |  VOBWMBTCynY=  |   POST / http send    | SPAN_KIND_INTERNAL | 1728707202838012024  | 1728707202838143694 |                                                                                                                                                                                                                                                                                                                                                                                                                   [{'key': 'asgi.event.type', 'value': {'string_value': 'http.response.body'}}]                                                                                                                                                                                                                                                                                                                                                                                                                   |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 72  | nG01YZoWtO0eJYhtVTOvvQ== | VOBWMBTCynY= |      nan       |        POST /         |  SPAN_KIND_SERVER  | 1728707202354435544  | 1728707202838205794 |     [{'key': 'http.scheme', 'value': {'string_value': 'http'}}, {'key': 'http.host', 'value': {'string_value': '10.244.0.11:8000'}}, {'key': 'net.host.port', 'value': {'int_value': '8000'}}, {'key': 'http.flavor', 'value': {'string_value': '1.1'}}, {'key': 'http.target', 'value': {'string_value': '/api/v1/transactions/'}}, {'key': 'http.url', 'value': {'string_value': 'http://10.244.0.11:8000/api/v1/transactions/'}}, {'key': 'http.method', 'value': {'string_value': 'POST'}}, {'key': 'http.server_name', 'value': {'string_value': '192.168.49.2:31670'}}, {'key': 'http.user_agent', 'value': {'string_value': 'python-requests/2.32.3'}}, {'key': 'net.peer.ip', 'value': {'string_value': '10.244.0.1'}}, {'key': 'net.peer.port', 'value': {'int_value': '12037'}}, {'key': 'http.route', 'value': {'string_value': '/'}}, {'key': 'http.status_code', 'value': {'int_value': '200'}}]     |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 73  | 1q+91AiRaGY4lyuGsnv/yw== | 0mn3T+MHCGA= |  5hRUp4YthEs=  |   POST / http send    | SPAN_KIND_INTERNAL | 1728707202851308624  | 1728707202851893894 |                                                                                                                                                                                                                                                                                                                                                                                    [{'key': 'asgi.event.type', 'value': {'string_value': 'http.response.start'}}, {'key': 'http.status_code', 'value': {'int_value': '200'}}]                                                                                                                                                                                                                                                                                                                                                                                     |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 74  | 1q+91AiRaGY4lyuGsnv/yw== | TWsiegb/Cqk= |  5hRUp4YthEs=  |   POST / http send    | SPAN_KIND_INTERNAL | 1728707202852023224  | 1728707202852100714 |                                                                                                                                                                                                                                                                                                                                                                                                                   [{'key': 'asgi.event.type', 'value': {'string_value': 'http.response.body'}}]                                                                                                                                                                                                                                                                                                                                                                                                                   |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 75  | 1q+91AiRaGY4lyuGsnv/yw== | 5hRUp4YthEs= |      nan       |        POST /         |  SPAN_KIND_SERVER  | 1728707201835361804  | 1728707202852120874 |     [{'key': 'http.scheme', 'value': {'string_value': 'http'}}, {'key': 'http.host', 'value': {'string_value': '10.244.0.11:8000'}}, {'key': 'net.host.port', 'value': {'int_value': '8000'}}, {'key': 'http.flavor', 'value': {'string_value': '1.1'}}, {'key': 'http.target', 'value': {'string_value': '/api/v1/transactions/'}}, {'key': 'http.url', 'value': {'string_value': 'http://10.244.0.11:8000/api/v1/transactions/'}}, {'key': 'http.method', 'value': {'string_value': 'POST'}}, {'key': 'http.server_name', 'value': {'string_value': '192.168.49.2:31670'}}, {'key': 'http.user_agent', 'value': {'string_value': 'python-requests/2.32.3'}}, {'key': 'net.peer.ip', 'value': {'string_value': '10.244.0.1'}}, {'key': 'net.peer.port', 'value': {'int_value': '29146'}}, {'key': 'http.route', 'value': {'string_value': '/'}}, {'key': 'http.status_code', 'value': {'int_value': '200'}}]     |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 76  | qJq7fRgAuWibBPDh6jI4iA== | WoMLu7cgS2U= |  YYdssY4iLYI=  |  POST / http receive  | SPAN_KIND_INTERNAL | 1728707202860725144  | 1728707202860779054 |                                                                                                                                                                                                                                                                                                                                                                                                                      [{'key': 'asgi.event.type', 'value': {'string_value': 'http.request'}}]                                                                                                                                                                                                                                                                                                                                                                                                                      |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 77  | aeuqxi5AqrjNnr9jrRepnw== | w1ynlXm1Kp4= |  q+N1kaINIlk=  |    GET / http send    | SPAN_KIND_INTERNAL | 1728707202875979154  | 1728707202876193984 |                                                                                                                                                                                                                                                                                                                                                                                    [{'key': 'asgi.event.type', 'value': {'string_value': 'http.response.start'}}, {'key': 'http.status_code', 'value': {'int_value': '200'}}]                                                                                                                                                                                                                                                                                                                                                                                     |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 78  | aeuqxi5AqrjNnr9jrRepnw== | mStxKPOJWRQ= |  q+N1kaINIlk=  |    GET / http send    | SPAN_KIND_INTERNAL | 1728707202876260944  | 1728707202876343564 |                                                                                                                                                                                                                                                                                                                                                                                                                   [{'key': 'asgi.event.type', 'value': {'string_value': 'http.response.body'}}]                                                                                                                                                                                                                                                                                                                                                                                                                   |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 79  | aeuqxi5AqrjNnr9jrRepnw== | q+N1kaINIlk= |      nan       |         GET /         |  SPAN_KIND_SERVER  | 1728707202856290034  | 1728707202876358144 |     [{'key': 'http.scheme', 'value': {'string_value': 'http'}}, {'key': 'http.host', 'value': {'string_value': '10.244.0.11:8000'}}, {'key': 'net.host.port', 'value': {'int_value': '8000'}}, {'key': 'http.flavor', 'value': {'string_value': '1.1'}}, {'key': 'http.target', 'value': {'string_value': '/api/v1/transactions/'}}, {'key': 'http.url', 'value': {'string_value': 'http://10.244.0.11:8000/api/v1/transactions/'}}, {'key': 'http.method', 'value': {'string_value': 'GET'}}, {'key': 'http.server_name', 'value': {'string_value': '192.168.49.2:31670'}}, {'key': 'http.user_agent', 'value': {'string_value': 'python-requests/2.32.3'}}, {'key': 'net.peer.ip', 'value': {'string_value': '10.244.0.1'}}, {'key': 'net.peer.port', 'value': {'int_value': '58779'}}, {'key': 'http.route', 'value': {'string_value': '/'}}, {'key': 'http.status_code', 'value': {'int_value': '200'}}]      |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 80  | qJq7fRgAuWibBPDh6jI4iA== | zVvBXQyld/Q= |  YYdssY4iLYI=  |   POST / http send    | SPAN_KIND_INTERNAL | 1728707202884036764  | 1728707202884395504 |                                                                                                                                                                                                                                                                                                                                                                                    [{'key': 'asgi.event.type', 'value': {'string_value': 'http.response.start'}}, {'key': 'http.status_code', 'value': {'int_value': '200'}}]                                                                                                                                                                                                                                                                                                                                                                                     |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 81  | qJq7fRgAuWibBPDh6jI4iA== | DWAu/bMfdGA= |  YYdssY4iLYI=  |   POST / http send    | SPAN_KIND_INTERNAL | 1728707202884526634  | 1728707202884613214 |                                                                                                                                                                                                                                                                                                                                                                                                                   [{'key': 'asgi.event.type', 'value': {'string_value': 'http.response.body'}}]                                                                                                                                                                                                                                                                                                                                                                                                                   |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 82  | qJq7fRgAuWibBPDh6jI4iA== | YYdssY4iLYI= |      nan       |        POST /         |  SPAN_KIND_SERVER  | 1728707202860405914  | 1728707202884637694 |     [{'key': 'http.scheme', 'value': {'string_value': 'http'}}, {'key': 'http.host', 'value': {'string_value': '10.244.0.11:8000'}}, {'key': 'net.host.port', 'value': {'int_value': '8000'}}, {'key': 'http.flavor', 'value': {'string_value': '1.1'}}, {'key': 'http.target', 'value': {'string_value': '/api/v1/transactions/'}}, {'key': 'http.url', 'value': {'string_value': 'http://10.244.0.11:8000/api/v1/transactions/'}}, {'key': 'http.method', 'value': {'string_value': 'POST'}}, {'key': 'http.server_name', 'value': {'string_value': '192.168.49.2:31670'}}, {'key': 'http.user_agent', 'value': {'string_value': 'python-requests/2.32.3'}}, {'key': 'net.peer.ip', 'value': {'string_value': '10.244.0.1'}}, {'key': 'net.peer.port', 'value': {'int_value': '5317'}}, {'key': 'http.route', 'value': {'string_value': '/'}}, {'key': 'http.status_code', 'value': {'int_value': '200'}}]      |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 83  | Jm8iGOaTZjdMfi6lxV7knA== | TwL3O5Gd0Ww= |  pHTQcxqtcrk=  |    GET / http send    | SPAN_KIND_INTERNAL | 1728707202918748684  | 1728707202919209754 |                                                                                                                                                                                                                                                                                                                                                                                    [{'key': 'asgi.event.type', 'value': {'string_value': 'http.response.start'}}, {'key': 'http.status_code', 'value': {'int_value': '200'}}]                                                                                                                                                                                                                                                                                                                                                                                     |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 84  | Jm8iGOaTZjdMfi6lxV7knA== | bjp1jbb+cY0= |  pHTQcxqtcrk=  |    GET / http send    | SPAN_KIND_INTERNAL | 1728707202919397494  | 1728707202919500994 |                                                                                                                                                                                                                                                                                                                                                                                                                   [{'key': 'asgi.event.type', 'value': {'string_value': 'http.response.body'}}]                                                                                                                                                                                                                                                                                                                                                                                                                   |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 85  | Jm8iGOaTZjdMfi6lxV7knA== | pHTQcxqtcrk= |      nan       |         GET /         |  SPAN_KIND_SERVER  | 1728707202861730804  | 1728707202919528804 |     [{'key': 'http.scheme', 'value': {'string_value': 'http'}}, {'key': 'http.host', 'value': {'string_value': '10.244.0.11:8000'}}, {'key': 'net.host.port', 'value': {'int_value': '8000'}}, {'key': 'http.flavor', 'value': {'string_value': '1.1'}}, {'key': 'http.target', 'value': {'string_value': '/api/v1/transactions/'}}, {'key': 'http.url', 'value': {'string_value': 'http://10.244.0.11:8000/api/v1/transactions/'}}, {'key': 'http.method', 'value': {'string_value': 'GET'}}, {'key': 'http.server_name', 'value': {'string_value': '192.168.49.2:31670'}}, {'key': 'http.user_agent', 'value': {'string_value': 'python-requests/2.32.3'}}, {'key': 'net.peer.ip', 'value': {'string_value': '10.244.0.1'}}, {'key': 'net.peer.port', 'value': {'int_value': '57933'}}, {'key': 'http.route', 'value': {'string_value': '/'}}, {'key': 'http.status_code', 'value': {'int_value': '200'}}]      |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 86  | n/cCESyUKt327iGAYCXqXQ== | tHa5vhA0fso= |  2pXRvunXvPA=  |  POST / http receive  | SPAN_KIND_INTERNAL | 1728707202923706154  | 1728707202923824144 |                                                                                                                                                                                                                                                                                                                                                                                                                      [{'key': 'asgi.event.type', 'value': {'string_value': 'http.request'}}]                                                                                                                                                                                                                                                                                                                                                                                                                      |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# | 87  | n/cCESyUKt327iGAYCXqXQ== | 1kPOFD7UrQ0= |  2pXRvunXvPA=  |   POST / http send    | SPAN_KIND_INTERNAL | 1728707202941786614  | 1728707202942403564 |                                                                                                                                                                                                                                                                                                                                                                                    [{'key': 'asgi.event.type', 'value': {'string_value': 'http.response.start'}}, {'key': 'http.status_code', 'value': {'int_value': '200'}}]                                                                                                                                                                                                                                                                                                                                                                                     |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.fastapi |    0.48b0     |
# ...
# | 132 | 1q+91AiRaGY4lyuGsnv/yw== | PuEinau0x98= |  5hRUp4YthEs=  |          GET          |  SPAN_KIND_CLIENT  | 1728707201837348374  | 1728707202824017924 |                                                                                                                                                                                                                                                                                                                                                 [{'key': 'http.method', 'value': {'string_value': 'GET'}}, {'key': 'http.url', 'value': {'string_value': 'http://auth:8080/api/v1/auth/authorize'}}, {'key': 'http.status_code', 'value': {'int_value': '200'}}]                                                                                                                                                                                                                                                                                                                                                  |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.urllib3 |    0.48b0     |
# | 133 | nG01YZoWtO0eJYhtVTOvvQ== | AxE2EHMjzgU= |  VOBWMBTCynY=  |         POST          |  SPAN_KIND_CLIENT  | 1728707202825102964  | 1728707202836720074 |                                                                                                                                                                                                                                                                                                                                       [{'key': 'http.method', 'value': {'string_value': 'POST'}}, {'key': 'http.url', 'value': {'string_value': 'http://tasking:8080/internal/v1/tasks/process_transaction'}}, {'key': 'http.status_code', 'value': {'int_value': '200'}}]                                                                                                                                                                                                                                                                                                                                        |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.urllib3 |    0.48b0     |
# | 134 | 1q+91AiRaGY4lyuGsnv/yw== | plkcdkurjko= |  5hRUp4YthEs=  |         POST          |  SPAN_KIND_CLIENT  | 1728707202840492334  | 1728707202850328884 |                                                                                                                                                                                                                                                                                                                                       [{'key': 'http.method', 'value': {'string_value': 'POST'}}, {'key': 'http.url', 'value': {'string_value': 'http://tasking:8080/internal/v1/tasks/process_transaction'}}, {'key': 'http.status_code', 'value': {'int_value': '200'}}]                                                                                                                                                                                                                                                                                                                                        |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.urllib3 |    0.48b0     |
# | 135 | aeuqxi5AqrjNnr9jrRepnw== | rkI2CDTvTZg= |  q+N1kaINIlk=  |          GET          |  SPAN_KIND_CLIENT  | 1728707202858695734  | 1728707202865116064 |                                                                                                                                                                                                                                                                                                                                                 [{'key': 'http.method', 'value': {'string_value': 'GET'}}, {'key': 'http.url', 'value': {'string_value': 'http://auth:8080/api/v1/auth/authorize'}}, {'key': 'http.status_code', 'value': {'int_value': '200'}}]                                                                                                                                                                                                                                                                                                                                                  |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.urllib3 |    0.48b0     |
# | 136 | qJq7fRgAuWibBPDh6jI4iA== | dO655bO3uGY= |  YYdssY4iLYI=  |          GET          |  SPAN_KIND_CLIENT  | 1728707202862920514  | 1728707202869923414 |                                                                                                                                                                                                                                                                                                                                                 [{'key': 'http.method', 'value': {'string_value': 'GET'}}, {'key': 'http.url', 'value': {'string_value': 'http://auth:8080/api/v1/auth/authorize'}}, {'key': 'http.status_code', 'value': {'int_value': '200'}}]                                                                                                                                                                                                                                                                                                                                                  |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.urllib3 |    0.48b0     |
# | 137 | Jm8iGOaTZjdMfi6lxV7knA== | l3j3jrdoLgw= |  pHTQcxqtcrk=  |          GET          |  SPAN_KIND_CLIENT  | 1728707202863781724  | 1728707202871462954 |                                                                                                                                                                                                                                                                                                                                                 [{'key': 'http.method', 'value': {'string_value': 'GET'}}, {'key': 'http.url', 'value': {'string_value': 'http://auth:8080/api/v1/auth/authorize'}}, {'key': 'http.status_code', 'value': {'int_value': '200'}}]                                                                                                                                                                                                                                                                                                                                                  |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.urllib3 |    0.48b0     |
# | 138 | aeuqxi5AqrjNnr9jrRepnw== | /FHeWEwY5Lg= |  q+N1kaINIlk=  |          GET          |  SPAN_KIND_CLIENT  | 1728707202866643634  | 1728707202875331154 |                                                                                                                                                                                                                                                                                                                                [{'key': 'http.method', 'value': {'string_value': 'GET'}}, {'key': 'http.url', 'value': {'string_value': 'http://dms:8080/internal/v1/data/transactions?user_id=49&skip=0&limit=10'}}, {'key': 'http.status_code', 'value': {'int_value': '200'}}]                                                                                                                                                                                                                                                                                                                                 |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.urllib3 |    0.48b0     |
# | 139 | qJq7fRgAuWibBPDh6jI4iA== | /7ntgysEErw= |  YYdssY4iLYI=  |         POST          |  SPAN_KIND_CLIENT  | 1728707202877469734  | 1728707202883192024 |                                                                                                                                                                                                                                                                                                                                       [{'key': 'http.method', 'value': {'string_value': 'POST'}}, {'key': 'http.url', 'value': {'string_value': 'http://tasking:8080/internal/v1/tasks/process_transaction'}}, {'key': 'http.status_code', 'value': {'int_value': '200'}}]                                                                                                                                                                                                                                                                                                                                        |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.urllib3 |    0.48b0     |
# | 140 | Jm8iGOaTZjdMfi6lxV7knA== | ZxZC7j/u2Yk= |  pHTQcxqtcrk=  |          GET          |  SPAN_KIND_CLIENT  | 1728707202885874744  | 1728707202918059914 |                                                                                                                                                                                                                                                                                                                                [{'key': 'http.method', 'value': {'string_value': 'GET'}}, {'key': 'http.url', 'value': {'string_value': 'http://dms:8080/internal/v1/data/transactions?user_id=47&skip=0&limit=10'}}, {'key': 'http.status_code', 'value': {'int_value': '200'}}]                                                                                                                                                                                                                                                                                                                                 |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.urllib3 |    0.48b0     |
# | 141 | n/cCESyUKt327iGAYCXqXQ== | Q+b5fQmr38U= |  2pXRvunXvPA=  |          GET          |  SPAN_KIND_CLIENT  | 1728707202925155874  | 1728707202929120284 |                                                                                                                                                                                                                                                                                                                                                 [{'key': 'http.method', 'value': {'string_value': 'GET'}}, {'key': 'http.url', 'value': {'string_value': 'http://auth:8080/api/v1/auth/authorize'}}, {'key': 'http.status_code', 'value': {'int_value': '200'}}]                                                                                                                                                                                                                                                                                                                                                  |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.urllib3 |    0.48b0     |
# | 142 | PdKuu+hlkzCmV8ZFH4qJNw== | svG42Fu8F9o= |  XvdiJsbpIDI=  |          GET          |  SPAN_KIND_CLIENT  | 1728707202930744874  | 1728707202937635994 |                                                                                                                                                                                                                                                                                                                                                 [{'key': 'http.method', 'value': {'string_value': 'GET'}}, {'key': 'http.url', 'value': {'string_value': 'http://auth:8080/api/v1/auth/authorize'}}, {'key': 'http.status_code', 'value': {'int_value': '200'}}]                                                                                                                                                                                                                                                                                                                                                  |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.urllib3 |    0.48b0     |
# | 143 | n/cCESyUKt327iGAYCXqXQ== | b2RkhSJcMUs= |  2pXRvunXvPA=  |         POST          |  SPAN_KIND_CLIENT  | 1728707202932651614  | 1728707202941010904 |                                                                                                                                                                                                                                                                                                                                       [{'key': 'http.method', 'value': {'string_value': 'POST'}}, {'key': 'http.url', 'value': {'string_value': 'http://tasking:8080/internal/v1/tasks/process_transaction'}}, {'key': 'http.status_code', 'value': {'int_value': '200'}}]                                                                                                                                                                                                                                                                                                                                        |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.urllib3 |    0.48b0     |
# | 144 | PdKuu+hlkzCmV8ZFH4qJNw== | ewq7z5VHCOQ= |  XvdiJsbpIDI=  |          GET          |  SPAN_KIND_CLIENT  | 1728707202944048674  | 1728707202961610734 |                                                                                                                                                                                                                                                                                                                                [{'key': 'http.method', 'value': {'string_value': 'GET'}}, {'key': 'http.url', 'value': {'string_value': 'http://dms:8080/internal/v1/data/transactions?user_id=48&skip=0&limit=10'}}, {'key': 'http.status_code', 'value': {'int_value': '200'}}]                                                                                                                                                                                                                                                                                                                                 |   {}   |  256  | Transactions Service | opentelemetry.instrumentation.urllib3 |    0.48b0     |
# +-----+--------------------------+--------------+----------------+-----------------------+--------------------+----------------------+---------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------+-------+----------------------+---------------------------------------+---------------+
